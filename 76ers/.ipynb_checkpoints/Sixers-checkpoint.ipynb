# %%
import pandas as pd
import time
import json
import numpy as np
import nbimporter
from PPP import PPP
np.seterr(invalid='ignore')
newGame = 'Heat2.27.23'

# %% [markdown]
# # Read in new files and load overall files

# %%
try:
    newEmbiidFile = (f'Embiid/Embiid{newGame}.csv')
    newEmbiid = pd.read_csv(newEmbiidFile)
    newEmbiid = newEmbiid.dropna()
    newEmbiid = newEmbiid.set_index('Shot Type')
    newEmbiid = newEmbiid.astype('int')
except(FileNotFoundError):
    print('No Embiid File Found.')

embiidFile = ('!Data/Embiid.csv')
embiid = pd.read_csv(embiidFile)
embiid = embiid.dropna()
embiid = embiid.set_index('Shot Type')
embiid = embiid.astype('int')

# %%
try:
    newHardenFile = (f'Harden/Harden{newGame}.csv')
    newHarden = pd.read_csv(newHardenFile)
    newHarden = newHarden.dropna()
    newHarden = newHarden.set_index("Shot Type")
    newHarden = newHarden.astype('int')
    newHarden
except(FileNotFoundError):
    print('No Harden file found')

hardenfile = ('!Data/Harden.csv')
harden = pd.read_csv(hardenfile)
harden = harden.dropna()
harden = harden.set_index('Shot Type')
harden = harden.astype('int')

# %%
try:
    newHarrisFile = (f'Harris/Harris{newGame}.csv')
    newHarris = pd.read_csv(newHarrisFile)
    newHarris = newHarris.dropna()
    newHarris = newHarris.set_index("Shot Type")
    newHarris = newHarris.astype('int')
    newHarris
except(FileNotFoundError):
    print('No Harris file found')

harrisfile = ('!Data/Harris.csv')
harris = pd.read_csv(harrisfile)
harris = harris.dropna()
harris = harris.set_index('Shot Type')
harris = harris.astype('int')

# %%
try:
    newMaxeyFile = (f'Maxey/Maxey{newGame}.csv')
    newMaxey = pd.read_csv(newMaxeyFile)
    newMaxey = newMaxey.dropna()
    newMaxey = newMaxey.set_index("Shot Type")
    newMaxey = newMaxey.astype('int')
    newMaxey
except(FileNotFoundError):
    print('No Maxey file found')

maxeyfile = ('!Data/Maxey.csv')
maxey = pd.read_csv(maxeyfile)
maxey = maxey.dropna()
maxey = maxey.set_index('Shot Type')
maxey = maxey.astype('int')

# %% [markdown]
# # Add new game data to overall data

# %%
if embiid.columns.equals(newEmbiid.columns):
    embiid = embiid.add(newEmbiid)
    embiid.to_csv('!Data/Embiid.csv')
else:
    print("Columns do not match")

# %%
if harden.columns.equals(newHarden.columns):
    harden = harden.add(newHarden)
    harden.to_csv('!Data/Harden.csv')
else:
    print("Columns do not match")

# %%
if harris.columns.equals(newHarris.columns):
    harris = harris.add(newHarris)
    harris.to_csv('!Data/Harris.csv')
else:
    print("Columns do not match")

# %%
if maxey.columns.equals(newMaxey.columns):
    maxey = maxey.add(newMaxey)
    maxey.to_csv('!Data/Maxey.csv')
else:
    print("Columns do not match")

# %% [markdown]
# # Calculate new Overall PPP and new game PPP, then write both to csv files

# %%
embiidStats = PPP(embiid)
embiidStats.to_csv('!PPP Stats/embiidStats.csv')
embiidStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# HARDEN                   1.63      14.2%     69.0%         1.45
# MAXEY                     1.7       0.7%       N/A          1.7
# MILTON                    N/A       0.0%       N/A          N/A
# MELTON                    3.0       0.8%    100.0%          N/A
# OTHERS                    2.0       0.8%    100.0%          N/A
# ISO                       1.2      63.9%     51.7%         1.28
# Transition               0.98       8.9%     61.5%         0.96
# Attacking Closeouts       1.5       4.1%     75.0%         1.71
# Catch & Shoot             0.0       2.9%      0.0%          0.0
# Off Ball Screens          N/A       0.0%       N/A          N/A
# Cutting                   0.0       0.4%      0.0%          0.0
# Off. Rebounds            0.57       3.6%     20.0%         1.05
# PNR / DHO                1.72      16.6%     72.7%         1.47
# TOTAL                    1.21        241     54.1%         1.23
#
#                     % of Shooting Poss. Shooting FG% Shooting 2pt Att.  \
# HARDEN                            15.6%        65.2%                23
# MAXEY                              1.0%          N/A                 0
# MILTON                             0.0%          N/A                 0
# MELTON                             0.0%          N/A                 0
# OTHERS                             0.0%          N/A                 0
# ISO                               63.0%        56.1%                79
# Transition                         9.7%        54.5%                10
# Attacking Closeouts                3.9%        71.4%                 7
# Catch & Shoot                      3.9%         0.0%                 1
# Off Ball Screens                   0.0%          N/A                 0
# Cutting                            0.6%         0.0%                 1
# Off. Rebounds                      2.6%        33.3%                 3
# PNR / DHO                         75.0%        65.2%                23
# TOTAL                             75.1%        54.5%               124
#
#                     Shooting 2pt FG% Shooting 3pt Att. Shooting 3pt FG%  \
# HARDEN                         65.2%                 0              N/A
# MAXEY                            N/A                 0              N/A
# MILTON                           N/A                 0              N/A
# MELTON                           N/A                 0              N/A
# OTHERS                           N/A                 0              N/A
# ISO                            57.0%                 3            33.3%
# Transition                     60.0%                 1             0.0%
# Attacking Closeouts            71.4%                 0              N/A
# Catch & Shoot                   0.0%                 6             0.0%
# Off Ball Screens                 N/A                 0              N/A
# Cutting                         0.0%                 0              N/A
# Off. Rebounds                  33.3%                 0              N/A
# PNR / DHO                      65.2%                 0              N/A
# TOTAL                          58.1%                10            10.0%
#
#                     Passing PPP % of Passing Poss. Passing FG%  \
# HARDEN                      2.5              10.0%       83.3%
# MAXEY                       N/A               0.0%         N/A
# MILTON                      N/A               0.0%         N/A
# MELTON                      3.0               3.3%      100.0%
# OTHERS                      2.0               3.3%      100.0%
# ISO                        0.95              66.5%       41.2%
# Transition                 1.06               6.3%      100.0%
# Attacking Closeouts         1.0               5.0%      100.0%
# Catch & Shoot               N/A               0.0%         N/A
# Off Ball Screens            N/A               0.0%         N/A
# Cutting                     N/A               0.0%         N/A
# Off. Rebounds               0.0               6.7%        0.0%
# PNR / DHO                     2              25.0%       90.0%
# TOTAL                      1.15              24.9%       53.1%
#
#                     Passing 2pt Att. Passing 2pt FG% Passing 3pt Att.  \
# HARDEN                             0             N/A                6
# MAXEY                              0             N/A                0
# MILTON                             0             N/A                0
# MELTON                             0             N/A                2
# OTHERS                             2          100.0%                0
# ISO                                9           55.6%               25
# Transition                         2          100.0%                0
# Attacking Closeouts                0             N/A                1
# Catch & Shoot                      0             N/A                0
# Off Ball Screens                   0             N/A                0
# Cutting                            0             N/A                0
# Off. Rebounds                      0             N/A                2
# PNR / DHO                          2          100.0%                8
# TOTAL                             13           69.2%               36
#
#                     Passing 3pt FG%
# HARDEN                        83.3%
# MAXEY                           N/A
# MILTON                          N/A
# MELTON                       100.0%
# OTHERS                          N/A
# ISO                           36.0%
# Transition                      N/A
# Attacking Closeouts          100.0%
# Catch & Shoot                   N/A
# Off Ball Screens                N/A
# Cutting                         N/A
# Off. Rebounds                  0.0%
# PNR / DHO                     87.5%
# TOTAL                         47.2%

# %%
newEmbiidStats = PPP(newEmbiid)
newEmbiidStats.to_csv(f'Embiid/PPP Stats/{newGame}.csv')
newEmbiidStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# HARDEN                   1.36      22.6%     60.0%         1.36
# MAXEY                     N/A       0.0%       N/A          N/A
# MILTON                    N/A       0.0%       N/A          N/A
# MELTON                    N/A       0.0%       N/A          N/A
# OTHERS                    N/A       0.0%       N/A          N/A
# ISO                      1.15      53.4%     60.0%         1.11
# Transition               1.33      11.5%     66.7%         1.33
# Attacking Closeouts       1.0       7.7%    100.0%          2.0
# Catch & Shoot             N/A       0.0%       N/A          N/A
# Off Ball Screens          N/A       0.0%       N/A          N/A
# Cutting                   N/A       0.0%       N/A          N/A
# Off. Rebounds             0.0       7.7%      0.0%          0.0
# PNR / DHO                 1.6      19.2%     60.0%          1.6
# TOTAL                    1.12         26     60.0%          1.2
#
#                     % of Shooting Poss. Shooting FG% Shooting 2pt Att.  \
# HARDEN                            29.4%        60.0%                 5
# MAXEY                              0.0%          N/A                 0
# MILTON                             0.0%          N/A                 0
# MELTON                             0.0%          N/A                 0
# OTHERS                             0.0%          N/A                 0
# ISO                               49.4%        57.1%                 7
# Transition                        15.0%        66.7%                 3
# Attacking Closeouts                5.0%       100.0%                 1
# Catch & Shoot                      0.0%          N/A                 0
# Off Ball Screens                   0.0%          N/A                 0
# Cutting                            0.0%          N/A                 0
# Off. Rebounds                      5.0%         0.0%                 1
# PNR / DHO                        100.0%        60.0%                 5
# TOTAL                             76.9%        58.8%                17
#
#                     Shooting 2pt FG% Shooting 3pt Att. Shooting 3pt FG%  \
# HARDEN                         60.0%                 0              N/A
# MAXEY                            N/A                 0              N/A
# MILTON                           N/A                 0              N/A
# MELTON                           N/A                 0              N/A
# OTHERS                           N/A                 0              N/A
# ISO                            57.1%                 0              N/A
# Transition                     66.7%                 0              N/A
# Attacking Closeouts           100.0%                 0              N/A
# Catch & Shoot                    N/A                 0              N/A
# Off Ball Screens                 N/A                 0              N/A
# Cutting                          N/A                 0              N/A
# Off. Rebounds                   0.0%                 0              N/A
# PNR / DHO                      60.0%                 0              N/A
# TOTAL                          58.8%                 0              N/A
#
#                     Passing PPP % of Passing Poss. Passing FG%  \
# HARDEN                      N/A               0.0%         N/A
# MAXEY                       N/A               0.0%         N/A
# MILTON                      N/A               0.0%         N/A
# MELTON                      N/A               0.0%         N/A
# OTHERS                      N/A               0.0%         N/A
# ISO                        1.25              66.7%       66.7%
# Transition                  N/A               0.0%         N/A
# Attacking Closeouts         0.0              16.7%         N/A
# Catch & Shoot               N/A               0.0%         N/A
# Off Ball Screens            N/A               0.0%         N/A
# Cutting                     N/A               0.0%         N/A
# Off. Rebounds               0.0              16.7%         N/A
# PNR / DHO                   N/A               0.0%         N/A
# TOTAL                      0.83              23.1%       66.7%
#
#                     Passing 2pt Att. Passing 2pt FG% Passing 3pt Att.  \
# HARDEN                             0             N/A                0
# MAXEY                              0             N/A                0
# MILTON                             0             N/A                0
# MELTON                             0             N/A                0
# OTHERS                             0             N/A                0
# ISO                                1          100.0%                2
# Transition                         0             N/A                0
# Attacking Closeouts                0             N/A                0
# Catch & Shoot                      0             N/A                0
# Off Ball Screens                   0             N/A                0
# Cutting                            0             N/A                0
# Off. Rebounds                      0             N/A                0
# PNR / DHO                          0             N/A                0
# TOTAL                              1          100.0%                2
#
#                     Passing 3pt FG%
# HARDEN                          N/A
# MAXEY                           N/A
# MILTON                          N/A
# MELTON                          N/A
# OTHERS                          N/A
# ISO                           50.0%
# Transition                      N/A
# Attacking Closeouts             N/A
# Catch & Shoot                   N/A
# Off Ball Screens                N/A
# Cutting                         N/A
# Off. Rebounds                   N/A
# PNR / DHO                       N/A
# TOTAL                         50.0%

# %%
hardenStats = PPP(harden)
hardenStats.to_csv('!PPP Stats/hardenStats.csv')
hardenStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# EMBIID                   1.32      24.4%     57.5%         1.25
# REED                     0.76       2.3%     40.0%          1.5
# NIANG                    0.44       2.0%     20.0%         0.61
# TUCKER                   1.44       5.6%     63.6%         1.75
# OTHERS                   0.77       6.4%     27.3%          0.0
# ISO                      1.22      32.4%     48.8%         1.31
# Transition               1.12      15.3%     51.2%         1.37
# Attacking Closeouts      1.53       4.0%     60.0%         1.53
# Catch & Shoot            1.29       6.1%     42.9%         1.11
# Off Ball Screens          3.0       0.6%    100.0%          N/A
# Cutting                   0.0       0.3%       N/A          0.0
# Off. Rebounds            2.25       1.2%    100.0%          2.0
# PNR / DHO                1.18      40.5%     50.0%          1.1
# TOTAL                    1.22        346     50.7%         1.25
#
#                     % of Shooting Poss. Shooting FG% Shooting 2pt Att.  \
# EMBIID                            13.9%        45.8%                 8
# REED                               1.1%        50.0%                 1
# NIANG                              2.7%        33.3%                 3
# TUCKER                             6.4%        66.7%                 4
# OTHERS                             5.0%         0.0%                 7
# ISO                               43.1%        45.0%                30
# Transition                         8.5%        60.0%                10
# Attacking Closeouts                6.6%        62.5%                 3
# Catch & Shoot                     10.6%        36.8%                 0
# Off Ball Screens                   0.0%          N/A                 0
# Cutting                            0.6%          N/A                 0
# Off. Rebounds                      1.7%       100.0%                 3
# PNR / DHO                         37.1%        38.6%                23
# TOTAL                             51.7%        45.1%                69
#
#                     Shooting 2pt FG% Shooting 3pt Att. Shooting 3pt FG%  \
# EMBIID                         50.0%                16            43.8%
# REED                            0.0%                 1           100.0%
# NIANG                          33.3%                 0              N/A
# TUCKER                         50.0%                 2           100.0%
# OTHERS                          0.0%                 2             0.0%
# ISO                            46.7%                30            43.3%
# Transition                     60.0%                 0              N/A
# Attacking Closeouts            33.3%                 5            80.0%
# Catch & Shoot                    N/A                19            36.8%
# Off Ball Screens                 N/A                 0              N/A
# Cutting                          N/A                 0              N/A
# Off. Rebounds                 100.0%                 0              N/A
# PNR / DHO                      30.4%                21            47.6%
# TOTAL                          44.9%                75            45.3%
#
#                     Passing PPP % of Passing Poss. Passing FG%  \
# EMBIID                     1.35              35.6%       63.3%
# REED                       0.51               3.5%       33.3%
# NIANG                       0.0               1.2%        0.0%
# TUCKER                      1.0               4.8%       60.0%
# OTHERS                     1.31               7.8%       46.2%
# ISO                        1.03              21.0%       57.7%
# Transition                 1.01              22.5%       48.4%
# Attacking Closeouts         1.5               1.2%       50.0%
# Catch & Shoot               3.0               1.2%      100.0%
# Off Ball Screens            3.0               1.2%      100.0%
# Cutting                     N/A               0.0%         N/A
# Off. Rebounds               3.0               0.6%      100.0%
# PNR / DHO                     1              62.9%       56.9%
# TOTAL                      1.19              48.3%       56.6%
#
#                     Passing 2pt Att. Passing 2pt FG% Passing 3pt Att.  \
# EMBIID                            36           61.1%               13
# REED                               3           33.3%                0
# NIANG                              0             N/A                2
# TUCKER                             3           33.3%                2
# OTHERS                             2          100.0%               11
# ISO                               12           75.0%               14
# Transition                        23           60.9%                8
# Attacking Closeouts                1            0.0%                1
# Catch & Shoot                      0             N/A                2
# Off Ball Screens                   0             N/A                2
# Cutting                            0             N/A                0
# Off. Rebounds                      0             N/A                1
# PNR / DHO                         44           59.1%               28
# TOTAL                             80           61.3%               56
#
#                     Passing 3pt FG%
# EMBIID                        69.2%
# REED                            N/A
# NIANG                          0.0%
# TUCKER                       100.0%
# OTHERS                        36.4%
# ISO                           42.9%
# Transition                    12.5%
# Attacking Closeouts          100.0%
# Catch & Shoot                100.0%
# Off Ball Screens             100.0%
# Cutting                         N/A
# Off. Rebounds                100.0%
# PNR / DHO                     53.6%
# TOTAL                         50.0%

# %%
newHardenStats = PPP(newHarden)
newHardenStats.to_csv(f'Harden/PPP Stats/{newGame}.csv')
newHardenStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# EMBIID                   1.24      23.4%     50.0%          1.0
# REED                      0.0       5.3%      0.0%          N/A
# NIANG                     N/A       0.0%       N/A          N/A
# TUCKER                   1.03      10.2%     50.0%         1.39
# OTHERS                    N/A       0.0%       N/A          N/A
# ISO                      1.42      26.0%     62.5%         1.19
# Transition                0.8      23.1%     28.6%          1.7
# Attacking Closeouts       1.5       5.3%     50.0%          1.5
# Catch & Shoot             1.0       7.9%     33.3%          0.0
# Off Ball Screens          3.0       2.6%    100.0%          N/A
# Cutting                   N/A       0.0%       N/A          N/A
# Off. Rebounds             N/A       0.0%       N/A          N/A
# PNR / DHO                1.15      34.2%     45.5%          1.4
# TOTAL                    1.14         38     46.9%         1.14
#
#                     % of Shooting Poss. Shooting FG% Shooting 2pt Att.  \
# EMBIID                            17.6%        33.3%                 0
# REED                               0.0%          N/A                 0
# NIANG                              0.0%          N/A                 0
# TUCKER                            16.9%        50.0%                 2
# OTHERS                             0.0%          N/A                 0
# ISO                               34.6%        40.0%                 4
# Transition                        10.4%          N/A                 0
# Attacking Closeouts               11.8%        50.0%                 1
# Catch & Shoot                     11.8%         0.0%                 0
# Off Ball Screens                   0.0%          N/A                 0
# Cutting                            0.0%          N/A                 0
# Off. Rebounds                      0.0%          N/A                 0
# PNR / DHO                         38.5%        40.0%                 2
# TOTAL                             44.7%        35.7%                 7
#
#                     Shooting 2pt FG% Shooting 3pt Att. Shooting 3pt FG%  \
# EMBIID                           N/A                 3            33.3%
# REED                             N/A                 0              N/A
# NIANG                            N/A                 0              N/A
# TUCKER                         50.0%                 0              N/A
# OTHERS                           N/A                 0              N/A
# ISO                            25.0%                 1           100.0%
# Transition                       N/A                 0              N/A
# Attacking Closeouts             0.0%                 1           100.0%
# Catch & Shoot                    N/A                 2             0.0%
# Off Ball Screens                 N/A                 0              N/A
# Cutting                          N/A                 0              N/A
# Off. Rebounds                    N/A                 0              N/A
# PNR / DHO                      50.0%                 3            33.3%
# TOTAL                          28.6%                 7            42.9%
#
#                     Passing PPP % of Passing Poss. Passing FG%  \
# EMBIID                     1.36              28.0%       60.0%
# REED                        0.0               9.5%        0.0%
# NIANG                       N/A               0.0%         N/A
# TUCKER                      0.0               4.8%         N/A
# OTHERS                      N/A               0.0%         N/A
# ISO                        1.75              19.0%      100.0%
# Transition                 0.57              33.3%       28.6%
# Attacking Closeouts         N/A               0.0%         N/A
# Catch & Shoot               3.0               4.8%      100.0%
# Off Ball Screens            3.0               4.8%      100.0%
# Cutting                     N/A               0.0%         N/A
# Off. Rebounds               N/A               0.0%         N/A
# PNR / DHO                     1              61.5%       50.0%
# TOTAL                      1.14              55.3%       55.6%
#
#                     Passing 2pt Att. Passing 2pt FG% Passing 3pt Att.  \
# EMBIID                             5           60.0%                0
# REED                               1            0.0%                0
# NIANG                              0             N/A                0
# TUCKER                             0             N/A                0
# OTHERS                             0             N/A                0
# ISO                                2          100.0%                1
# Transition                         4           50.0%                3
# Attacking Closeouts                0             N/A                0
# Catch & Shoot                      0             N/A                1
# Off Ball Screens                   0             N/A                1
# Cutting                            0             N/A                0
# Off. Rebounds                      0             N/A                0
# PNR / DHO                          6           50.0%                0
# TOTAL                             12           58.3%                6
#
#                     Passing 3pt FG%
# EMBIID                          N/A
# REED                            N/A
# NIANG                           N/A
# TUCKER                          N/A
# OTHERS                          N/A
# ISO                          100.0%
# Transition                     0.0%
# Attacking Closeouts             N/A
# Catch & Shoot                100.0%
# Off Ball Screens             100.0%
# Cutting                         N/A
# Off. Rebounds                   N/A
# PNR / DHO                       N/A
# TOTAL                         50.0%

# %%
harrisStats = PPP(harris)
harrisStats.to_csv('!PPP Stats/HarrisStats.csv')
harrisStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# EMBIID                   1.23       7.7%     50.0%         1.55
# REED                      N/A       0.0%       N/A          N/A
# TUCKER                    N/A       0.0%       N/A          N/A
# HARRELL                   N/A       0.0%       N/A          N/A
# OTHERS                    0.0       1.6%       N/A          0.0
# ISO                      0.22      14.3%     20.0%         0.33
# Transition               1.88      20.3%     81.8%          1.8
# Attacking Closeouts       0.8      15.9%     37.5%         0.25
# Catch & Shoot            1.35      31.7%     45.0%         1.35
# Off Ball Screens         1.33       4.8%     66.7%         1.33
# Cutting                  0.67       4.8%     33.3%         0.67
# Off. Rebounds             N/A       0.0%       N/A          N/A
# PNR / DHO                 1.2       7.9%     50.0%          1.5
# TOTAL                    1.15         63     50.0%         1.08
#
#                     % of Shooting Poss. Shooting FG% Shooting 2pt Att.  \
# EMBIID                             7.5%        66.7%                 3
# REED                               0.0%          N/A                 0
# TUCKER                             0.0%          N/A                 0
# HARRELL                            0.0%          N/A                 0
# OTHERS                             1.9%          N/A                 0
# ISO                               11.5%        25.0%                 4
# Transition                        14.9%        83.3%                 4
# Attacking Closeouts               15.4%        16.7%                 6
# Catch & Shoot                     38.5%        45.0%                 0
# Off Ball Screens                   5.8%        66.7%                 2
# Cutting                            5.8%        33.3%                 3
# Off. Rebounds                      0.0%          N/A                 0
# PNR / DHO                         80.0%        66.7%                 3
# TOTAL                             82.5%        46.7%                22
#
#                     Shooting 2pt FG% Shooting 3pt Att. Shooting 3pt FG%  \
# EMBIID                         66.7%                 0              N/A
# REED                             N/A                 0              N/A
# TUCKER                           N/A                 0              N/A
# HARRELL                          N/A                 0              N/A
# OTHERS                           N/A                 0              N/A
# ISO                            25.0%                 0              N/A
# Transition                     75.0%                 2           100.0%
# Attacking Closeouts            16.7%                 0              N/A
# Catch & Shoot                    N/A                20            45.0%
# Off Ball Screens              100.0%                 1             0.0%
# Cutting                        33.3%                 0              N/A
# Off. Rebounds                    N/A                 0              N/A
# PNR / DHO                      66.7%                 0              N/A
# TOTAL                          45.5%                23            47.8%
#
#                     Passing PPP % of Passing Poss. Passing FG%  \
# EMBIID                      0.0               9.1%        0.0%
# REED                        N/A               0.0%         N/A
# TUCKER                      N/A               0.0%         N/A
# HARRELL                     N/A               0.0%         N/A
# OTHERS                      N/A               0.0%         N/A
# ISO                         0.0              27.3%        0.0%
# Transition                  2.0              45.5%       80.0%
# Attacking Closeouts         3.0              18.2%      100.0%
# Catch & Shoot               N/A               0.0%         N/A
# Off Ball Screens            N/A               0.0%         N/A
# Cutting                     N/A               0.0%         N/A
# Off. Rebounds               N/A               0.0%         N/A
# PNR / DHO                     0              20.0%        0.0%
# TOTAL                      1.45              17.5%       66.7%
#
#                     Passing 2pt Att. Passing 2pt FG% Passing 3pt Att.  \
# EMBIID                             1            0.0%                0
# REED                               0             N/A                0
# TUCKER                             0             N/A                0
# HARRELL                            0             N/A                0
# OTHERS                             0             N/A                0
# ISO                                0             N/A                1
# Transition                         2          100.0%                3
# Attacking Closeouts                0             N/A                2
# Catch & Shoot                      0             N/A                0
# Off Ball Screens                   0             N/A                0
# Cutting                            0             N/A                0
# Off. Rebounds                      0             N/A                0
# PNR / DHO                          1            0.0%                0
# TOTAL                              3           66.7%                6
#
#                     Passing 3pt FG%
# EMBIID                          N/A
# REED                            N/A
# TUCKER                          N/A
# HARRELL                         N/A
# OTHERS                          N/A
# ISO                            0.0%
# Transition                    66.7%
# Attacking Closeouts          100.0%
# Catch & Shoot                   N/A
# Off Ball Screens                N/A
# Cutting                         N/A
# Off. Rebounds                   N/A
# PNR / DHO                       N/A
# TOTAL                         66.7%

# %%
newHarrisStats = PPP(newHarris)
newHarrisStats.to_csv(f'Harris/PPP Stats/{newGame}.csv')
newHarrisStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# EMBIID                    N/A       0.0%       N/A          N/A
# REED                      N/A       0.0%       N/A          N/A
# TUCKER                    N/A       0.0%       N/A          N/A
# HARRELL                   N/A       0.0%       N/A          N/A
# OTHERS                    N/A       0.0%       N/A          N/A
# ISO                       0.0      12.5%       N/A          N/A
# Transition                2.0      12.5%    100.0%          N/A
# Attacking Closeouts       1.0      37.5%     50.0%          0.0
# Catch & Shoot             0.0      25.0%      0.0%          0.0
# Off Ball Screens          2.0      12.5%    100.0%          2.0
# Cutting                   N/A       0.0%       N/A          N/A
# Off. Rebounds             N/A       0.0%       N/A          N/A
# PNR / DHO                 N/A       0.0%      nan%          N/A
# TOTAL                    0.88          8     50.0%          0.4
#
#                     % of Shooting Poss. Shooting FG% Shooting 2pt Att.  \
# EMBIID                             0.0%          N/A                 0
# REED                               0.0%          N/A                 0
# TUCKER                             0.0%          N/A                 0
# HARRELL                            0.0%          N/A                 0
# OTHERS                             0.0%          N/A                 0
# ISO                                0.0%          N/A                 0
# Transition                         0.0%          N/A                 0
# Attacking Closeouts               40.0%         0.0%                 1
# Catch & Shoot                     40.0%         0.0%                 0
# Off Ball Screens                  20.0%       100.0%                 1
# Cutting                            0.0%          N/A                 0
# Off. Rebounds                      0.0%          N/A                 0
# PNR / DHO                           N/A         nan%                 0
# TOTAL                             62.5%        25.0%                 2
#
#                     Shooting 2pt FG% Shooting 3pt Att. Shooting 3pt FG%  \
# EMBIID                           N/A                 0              N/A
# REED                             N/A                 0              N/A
# TUCKER                           N/A                 0              N/A
# HARRELL                          N/A                 0              N/A
# OTHERS                           N/A                 0              N/A
# ISO                              N/A                 0              N/A
# Transition                       N/A                 0              N/A
# Attacking Closeouts             0.0%                 0              N/A
# Catch & Shoot                    N/A                 2             0.0%
# Off Ball Screens              100.0%                 0              N/A
# Cutting                          N/A                 0              N/A
# Off. Rebounds                    N/A                 0              N/A
# PNR / DHO                       nan%                 0              N/A
# TOTAL                          50.0%                 2             0.0%
#
#                     Passing PPP % of Passing Poss. Passing FG%  \
# EMBIID                      N/A               0.0%         N/A
# REED                        N/A               0.0%         N/A
# TUCKER                      N/A               0.0%         N/A
# HARRELL                     N/A               0.0%         N/A
# OTHERS                      N/A               0.0%         N/A
# ISO                         0.0              33.3%         N/A
# Transition                  2.0              33.3%      100.0%
# Attacking Closeouts         3.0              33.3%      100.0%
# Catch & Shoot               N/A               0.0%         N/A
# Off Ball Screens            N/A               0.0%         N/A
# Cutting                     N/A               0.0%         N/A
# Off. Rebounds               N/A               0.0%         N/A
# PNR / DHO                   N/A                N/A         N/A
# TOTAL                      1.67              37.5%      100.0%
#
#                     Passing 2pt Att. Passing 2pt FG% Passing 3pt Att.  \
# EMBIID                             0             N/A                0
# REED                               0             N/A                0
# TUCKER                             0             N/A                0
# HARRELL                            0             N/A                0
# OTHERS                             0             N/A                0
# ISO                                0             N/A                0
# Transition                         1          100.0%                0
# Attacking Closeouts                0             N/A                1
# Catch & Shoot                      0             N/A                0
# Off Ball Screens                   0             N/A                0
# Cutting                            0             N/A                0
# Off. Rebounds                      0             N/A                0
# PNR / DHO                          0             N/A                0
# TOTAL                              1          100.0%                1
#
#                     Passing 3pt FG%
# EMBIID                          N/A
# REED                            N/A
# TUCKER                          N/A
# HARRELL                         N/A
# OTHERS                          N/A
# ISO                             N/A
# Transition                      N/A
# Attacking Closeouts          100.0%
# Catch & Shoot                   N/A
# Off Ball Screens                N/A
# Cutting                         N/A
# Off. Rebounds                   N/A
# PNR / DHO                       N/A
# TOTAL                        100.0%

# %%
maxeyStats = PPP(maxey)
maxeyStats.to_csv('!PPP Stats/maxeyStats.csv')
maxeyStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# EMBIID                   1.24      17.7%     50.0%          0.8
# REED                     1.43       3.5%     71.4%          1.2
# TUCKER                   1.02       2.4%     25.0%         1.02
# NIANG                     1.0       2.5%     40.0%          0.0
# OTHERS                   1.33       4.5%     55.6%         1.14
# ISO                       1.2      27.8%     52.4%         1.28
# Transition               1.07      18.6%     48.0%         0.95
# Attacking Closeouts      1.11       9.8%     56.2%         1.31
# Catch & Shoot            1.04      11.4%     34.8%         1.04
# Off Ball Screens          2.0       2.0%     75.0%         1.67
# Cutting                   N/A       0.0%       N/A          N/A
# Off. Rebounds             0.0       0.5%      0.0%          N/A
# PNR / DHO                1.27      29.9%     50.9%         0.88
# TOTAL                    1.17        201     49.4%         1.09
#
#                     % of Shooting Poss. Shooting FG% Shooting 2pt Att.  \
# EMBIID                            14.7%        38.1%                15
# REED                               3.1%        60.0%                 5
# TUCKER                             3.0%        25.0%                 2
# NIANG                              1.8%         0.0%                 0
# OTHERS                             4.3%        42.9%                 4
# ISO                               28.7%        57.6%                30
# Transition                        18.7%        35.0%                14
# Attacking Closeouts               10.3%        69.2%                13
# Catch & Shoot                     14.1%        34.8%                 0
# Off Ball Screens                   1.8%        66.7%                 1
# Cutting                            0.0%          N/A                 0
# Off. Rebounds                      0.0%          N/A                 0
# PNR / DHO                         71.7%        37.5%                26
# TOTAL                             81.1%        45.5%                84
#
#                     Shooting 2pt FG% Shooting 3pt Att. Shooting 3pt FG%  \
# EMBIID                         46.7%                 6            16.7%
# REED                           60.0%                 0              N/A
# TUCKER                          0.0%                 2            50.0%
# NIANG                            N/A                 3             0.0%
# OTHERS                         25.0%                 3            66.7%
# ISO                            56.7%                 3            66.7%
# Transition                     50.0%                 6             0.0%
# Attacking Closeouts            69.2%                 0              N/A
# Catch & Shoot                    N/A                23            34.8%
# Off Ball Screens              100.0%                 2            50.0%
# Cutting                          N/A                 0              N/A
# Off. Rebounds                    N/A                 0              N/A
# PNR / DHO                      42.3%                14            28.6%
# TOTAL                          53.6%                48            31.2%
#
#                     Passing PPP % of Passing Poss. Passing FG%  \
# EMBIID                     2.15              30.6%       77.8%
# REED                        2.0               5.3%      100.0%
# TUCKER                      N/A               0.0%         N/A
# NIANG                       2.5               5.3%      100.0%
# OTHERS                      2.0               5.3%      100.0%
# ISO                        0.78              23.7%       33.3%
# Transition                  1.6              18.1%      100.0%
# Attacking Closeouts         0.0               7.9%        0.0%
# Catch & Shoot               N/A               0.0%         N/A
# Off Ball Screens            3.0               2.6%      100.0%
# Cutting                     N/A               0.0%         N/A
# Off. Rebounds               0.0               2.6%        0.0%
# PNR / DHO                     2              28.3%       86.7%
# TOTAL                      1.53              18.9%       64.7%
#
#                     Passing 2pt Att. Passing 2pt FG% Passing 3pt Att.  \
# EMBIID                             3           66.7%                6
# REED                               2          100.0%                0
# TUCKER                             0             N/A                0
# NIANG                              1          100.0%                1
# OTHERS                             2          100.0%                0
# ISO                                4           50.0%                5
# Transition                         4          100.0%                1
# Attacking Closeouts                0             N/A                3
# Catch & Shoot                      0             N/A                0
# Off Ball Screens                   0             N/A                1
# Cutting                            0             N/A                0
# Off. Rebounds                      0             N/A                1
# PNR / DHO                          8           87.5%                7
# TOTAL                             16           81.2%               18
#
#                     Passing 3pt FG%
# EMBIID                        83.3%
# REED                            N/A
# TUCKER                          N/A
# NIANG                        100.0%
# OTHERS                          N/A
# ISO                           20.0%
# Transition                   100.0%
# Attacking Closeouts            0.0%
# Catch & Shoot                   N/A
# Off Ball Screens             100.0%
# Cutting                         N/A
# Off. Rebounds                  0.0%
# PNR / DHO                     85.7%
# TOTAL                         50.0%

# %%
newMaxeyStats = PPP(newMaxey)
newMaxeyStats.to_csv(f'Maxey/PPP Stats/{newGame}.csv')
newMaxeyStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# EMBIID                   1.36      22.6%     60.0%         1.36
# REED                      N/A       0.0%       N/A          N/A
# TUCKER                    N/A       0.0%       N/A          N/A
# NIANG                     N/A       0.0%       N/A          N/A
# OTHERS                    N/A       0.0%       N/A          N/A
# ISO                      1.15      53.4%     60.0%         1.11
# Transition               1.33      11.5%     66.7%         1.33
# Attacking Closeouts       1.0       7.7%    100.0%          2.0
# Catch & Shoot             N/A       0.0%       N/A          N/A
# Off Ball Screens          N/A       0.0%       N/A          N/A
# Cutting                   N/A       0.0%       N/A          N/A
# Off. Rebounds             0.0       7.7%      0.0%          0.0
# PNR / DHO                 1.6      19.2%     60.0%          1.6
# TOTAL                    1.12         26     60.0%          1.2
#
#                     % of Shooting Poss. Shooting FG% Shooting 2pt Att.  \
# EMBIID                            29.4%        60.0%                 5
# REED                               0.0%          N/A                 0
# TUCKER                             0.0%          N/A                 0
# NIANG                              0.0%          N/A                 0
# OTHERS                             0.0%          N/A                 0
# ISO                               49.4%        57.1%                 7
# Transition                        15.0%        66.7%                 3
# Attacking Closeouts                5.0%       100.0%                 1
# Catch & Shoot                      0.0%          N/A                 0
# Off Ball Screens                   0.0%          N/A                 0
# Cutting                            0.0%          N/A                 0
# Off. Rebounds                      5.0%         0.0%                 1
# PNR / DHO                        100.0%        60.0%                 5
# TOTAL                             76.9%        58.8%                17
#
#                     Shooting 2pt FG% Shooting 3pt Att. Shooting 3pt FG%  \
# EMBIID                         60.0%                 0              N/A
# REED                             N/A                 0              N/A
# TUCKER                           N/A                 0              N/A
# NIANG                            N/A                 0              N/A
# OTHERS                           N/A                 0              N/A
# ISO                            57.1%                 0              N/A
# Transition                     66.7%                 0              N/A
# Attacking Closeouts           100.0%                 0              N/A
# Catch & Shoot                    N/A                 0              N/A
# Off Ball Screens                 N/A                 0              N/A
# Cutting                          N/A                 0              N/A
# Off. Rebounds                   0.0%                 0              N/A
# PNR / DHO                      60.0%                 0              N/A
# TOTAL                          58.8%                 0              N/A
#
#                     Passing PPP % of Passing Poss. Passing FG%  \
# EMBIID                      N/A               0.0%         N/A
# REED                        N/A               0.0%         N/A
# TUCKER                      N/A               0.0%         N/A
# NIANG                       N/A               0.0%         N/A
# OTHERS                      N/A               0.0%         N/A
# ISO                        1.25              66.7%       66.7%
# Transition                  N/A               0.0%         N/A
# Attacking Closeouts         0.0              16.7%         N/A
# Catch & Shoot               N/A               0.0%         N/A
# Off Ball Screens            N/A               0.0%         N/A
# Cutting                     N/A               0.0%         N/A
# Off. Rebounds               0.0              16.7%         N/A
# PNR / DHO                   N/A               0.0%         N/A
# TOTAL                      0.83              23.1%       66.7%
#
#                     Passing 2pt Att. Passing 2pt FG% Passing 3pt Att.  \
# EMBIID                             0             N/A                0
# REED                               0             N/A                0
# TUCKER                             0             N/A                0
# NIANG                              0             N/A                0
# OTHERS                             0             N/A                0
# ISO                                1          100.0%                2
# Transition                         0             N/A                0
# Attacking Closeouts                0             N/A                0
# Catch & Shoot                      0             N/A                0
# Off Ball Screens                   0             N/A                0
# Cutting                            0             N/A                0
# Off. Rebounds                      0             N/A                0
# PNR / DHO                          0             N/A                0
# TOTAL                              1          100.0%                2
#
#                     Passing 3pt FG%
# EMBIID                          N/A
# REED                            N/A
# TUCKER                          N/A
# NIANG                           N/A
# OTHERS                          N/A
# ISO                           50.0%
# Transition                      N/A
# Attacking Closeouts             N/A
# Catch & Shoot                   N/A
# Off Ball Screens                N/A
# Cutting                         N/A
# Off. Rebounds                   N/A
# PNR / DHO                       N/A
# TOTAL                         50.0%

# %%
def BoxScore(data):
    
    # Assign index and column headers
    headers = ['Points', 'AST', 'Points Created', 'TO', 'FG', '3PT', 'OREB', 'TOTAL']
    index = data.columns
    
    # Assign PNR Data
    PNRData = data.iloc[:,:5]
    
    # Assign PNR variables
    PNRshoot2FGA = PNRData.loc['shoot2FGA'].sum().sum()
    PNRshoot2FGM = PNRData.loc['shoot2FGM'].sum().sum()
    PNRshoot2FTA = PNRData.loc['shoot2FTA'].sum().sum()
    PNRshoot2FTM = PNRData.loc['shoot2FTM'].sum().sum()
    PNRshoot2TO = PNRData.loc['shoot2TO'].sum().sum()
    PNRshoot3FGA = PNRData.loc['shoot3FGA'].sum().sum()
    PNRshoot3FGM = PNRData.loc['shoot3FGM'].sum().sum()
    PNRshoot3FTA = PNRData.loc['shoot3FTA'].sum().sum()
    PNRshoot3FTM = PNRData.loc['shoot3FTM'].sum().sum()
    PNRshoot3TO = PNRData.loc['shoot3TO'].sum().sum()
    
    PNRpass2FGA = PNRData.loc['pass2FGA'].sum().sum()
    PNRpass2FGM = PNRData.loc['pass2FGM'].sum().sum()
    PNRpass2FTA = PNRData.loc['pass2FTA'].sum().sum()
    PNRpass2FTM = PNRData.loc['pass2FTM'].sum().sum()
    PNRpass2TO = PNRData.loc['pass2TO'].sum().sum()
    PNRpass3FGA = PNRData.loc['pass3FGA'].sum().sum()
    PNRpass3FGM = PNRData.loc['pass3FGM'].sum().sum()
    PNRpass3FTA = PNRData.loc['pass3FTA'].sum().sum()
    PNRpass3FTM = PNRData.loc['pass3FTM'].sum().sum()
    PNRpass3TO = PNRData.loc['pass3TO'].sum().sum()
    
    PNRFGA2 = PNRpass2FGA + PNRshoot2FGA
    PNRFGM2 = PNRpass2FGM + PNRshoot2FGM
    PNRFTA2 = PNRpass2FTA + PNRshoot2FTA
    PNRFTM2 = PNRpass2FTM + PNRshoot2FTM
    PNRTO2 = PNRpass2TO + PNRshoot2TO
    PNRFGA3 = PNRpass3FGA + PNRshoot3FGA
    PNRFGM3 = PNRpass3FGM + PNRshoot3FGM
    PNRFTA3 = PNRpass3FTA + PNRshoot3FTA
    PNRFTM3 = PNRpass3FTM + PNRshoot3FTM
    PNRTO3 = PNRpass3TO + PNRshoot3TO
    
    # Assign shooting data to new variables
    shoot2FGA = data.loc['shoot2FGA'].sum().sum()
    shoot2FGM = data.loc['shoot2FGM'].sum().sum()
    shoot2FTA = data.loc['shoot2FTA'].sum().sum()
    shoot2FTM = data.loc['shoot2FTM'].sum().sum()
    shoot2TO = data.loc['shoot2TO'].sum().sum()
    shoot3FGA = data.loc['shoot3FGA'].sum().sum()
    shoot3FGM = data.loc['shoot3FGM'].sum().sum()
    shoot3FTA = data.loc['shoot3FTA'].sum().sum()
    shoot3FTM = data.loc['shoot3FTM'].sum().sum()
    shoot3TO = data.loc['shoot3TO'].sum().sum()
    
    # Assign passing data to new variables
    pass2FGA = data.loc['pass2FGA'].sum().sum()
    pass2FGM = data.loc['pass2FGM'].sum().sum()
    pass2FTA = data.loc['pass2FTA'].sum().sum()
    pass2FTM = data.loc['pass2FTM'].sum().sum()
    pass2TO = data.loc['pass2TO'].sum().sum()
    pass3FGA = data.loc['pass3FGA'].sum().sum()
    pass3FGM = data.loc['pass3FGM'].sum().sum()
    pass3FTA = data.loc['pass3FTA'].sum().sum()
    pass3FTM = data.loc['pass3FTM'].sum().sum()
    pass3TO = data.loc['pass3TO'].sum().sum()
    
    # Create Overall data variables
    FGA2 = pass2FGA + shoot2FGA
    FGM2 = pass2FGM + shoot2FGM
    FTA2 = pass2FTA + shoot2FTA
    FTM2 = pass2FTM + shoot2FTM
    TO2 = pass2TO + shoot2TO
    FGA3 = pass3FGA + shoot3FGA
    FGM3 = pass3FGM + shoot3FGM
    FTA3 = pass3FTA + shoot3FTA
    FTM3 = pass3FTM + shoot3FTM
    TO3 = pass3TO + shoot3TO
    
    pts = (FGA2 * 2) + (FGA3 * 3) + FTM2 + FTM3
    
    data_df = pd.DataFrame(columns=headers, index=index)
    data_df['TOTAL'] = pts
    col_dicts = {col_name: data[col_name].to_dict() for col_name in data.columns}
    data_df = data_df.transpose()
    data_df['TOTAL'] = pts
    return(data_df)

# %%
BoxScore(embiid)
# Out:
#                HARDEN MAXEY MILTON MELTON OTHERS  ISO TRAN  ACO  C/S  OBS  \
# Points            NaN   NaN    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN
# AST               NaN   NaN    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN
# Points Created    NaN   NaN    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN
# TO                NaN   NaN    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN
# FG                NaN   NaN    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN
# 3PT               NaN   NaN    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN
# OREB              NaN   NaN    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN
# TOTAL             490   490    490    490    490  490  490  490  490  490
#
#                 CUT OREB  TOTAL
# Points          NaN  NaN    490
# AST             NaN  NaN    490
# Points Created  NaN  NaN    490
# TO              NaN  NaN    490
# FG              NaN  NaN    490
# 3PT             NaN  NaN    490
# OREB            NaN  NaN    490
# TOTAL           490  490    490
