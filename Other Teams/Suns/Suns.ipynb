# %%
import pandas as pd
import time
import json
import numpy as np
np.seterr(invalid='ignore')
import nbimporter
from PPP import PPP

# Set newGame variable
newGame = 'Game6Nuggets'
Opp = 'Nuggets'

# %% [markdown]
# # Read in new files and load overall files

# %%
# Load new game data if it exists
try:
    newAytonFile = (f'Ayton/{newGame}Ayton.csv')
    newAyton = pd.read_csv(newAytonFile)
    newAyton = newAyton.dropna()
    newAyton = newAyton.set_index('Shot Type')
    newAyton = newAyton.astype('int')
except(FileNotFoundError):
    print('No Ayton File Found.')

# Load overall data
aytonFile = ('!Data/Ayton.csv')
ayton = pd.read_csv(aytonFile)
ayton = ayton.dropna()
ayton = ayton.set_index('Shot Type')
ayton = ayton.astype('int')
# Out:
# No Ayton File Found.

# %%
try:
    newBiyomboFile = (f'Biyombo/{newGame}Biyombo.csv')
    newBiyombo = pd.read_csv(newBiyomboFile)
    newBiyombo = newBiyombo.dropna()
    newBiyombo = newBiyombo.set_index("Shot Type")
    newBiyombo = newBiyombo.astype('int')
except(FileNotFoundError):
    print('No Biyombo file found')

biyombofile = ('!Data/Biyombo.csv')
biyombo = pd.read_csv(biyombofile)
biyombo = biyombo.dropna()
biyombo = biyombo.set_index('Shot Type')
biyombo = biyombo.astype('int')

# %%
try:
    newBookerFile = (f'Booker/{newGame}Booker.csv')
    newBooker = pd.read_csv(newBookerFile)
    newBooker = newBooker.dropna()
    newBooker = newBooker.set_index("Shot Type")
    newBooker = newBooker.astype('int')
except(FileNotFoundError):
    print('No Booker file found')

bookerfile = ('!Data/Booker.csv')
booker = pd.read_csv(bookerfile)
booker = booker.dropna()
booker = booker.set_index('Shot Type')
booker = booker.astype('int')

# %%
try:
    newCraigFile = (f'Craig/{newGame}Craig.csv')
    newCraig = pd.read_csv(newCraigFile)
    newCraig = newCraig.dropna()
    newCraig = newCraig.set_index("Shot Type")
    newCraig = newCraig.astype('int')
except(FileNotFoundError):
    print('No Craig file found')

craigfile = ('!Data/Craig.csv')
craig = pd.read_csv(craigfile)
craig = craig.dropna()
craig = craig.set_index('Shot Type')
craig = craig.astype('int')

# %%
try:
    newDurantFile = (f'Durant/{newGame}Durant.csv')
    newDurant = pd.read_csv(newDurantFile)
    newDurant = newDurant.dropna()
    newDurant = newDurant.set_index("Shot Type")
    newDurant = newDurant.astype('int')
except(FileNotFoundError):
    print('No Durant file found')

durantfile = ('!Data/Durant.csv')
durant = pd.read_csv(durantfile)
durant = durant.dropna()
durant = durant.set_index('Shot Type')
durant = durant.astype('int')

# %%
try:
    newLandaleFile = (f'Landale/{newGame}Landale.csv')
    newLandale = pd.read_csv(newLandaleFile)
    newLandale = newLandale.dropna()
    newLandale = newLandale.set_index("Shot Type")
    newLandale = newLandale.astype('int')
except(FileNotFoundError):
    print('No Landale file found')

landalefile = ('!Data/Landale.csv')
landale = pd.read_csv(landalefile)
landale = landale.dropna()
landale = landale.set_index('Shot Type')
landale = landale.astype('int')

# %%
try:
    newLeeFile = (f'Lee/{newGame}Lee.csv')
    newLee = pd.read_csv(newLeeFile)
    newLee = newLee.dropna()
    newLee = newLee.set_index("Shot Type")
    newLee = newLee.astype('int')
except(FileNotFoundError):
    print('No Lee file found')

leefile = ('!Data/Lee.csv')
lee = pd.read_csv(leefile)
lee = lee.dropna()
lee = lee.set_index('Shot Type')
lee = lee.astype('int')

# %%
try:
    newOkogieFile = (f'Okogie/{newGame}Okogie.csv')
    newOkogie = pd.read_csv(newOkogieFile)
    newOkogie = newOkogie.dropna()
    newOkogie = newOkogie.set_index("Shot Type")
    newOkogie = newOkogie.astype('int')
except(FileNotFoundError):
    print('No Okogie file found')

okogiefile = ('!Data/Okogie.csv')
okogie = pd.read_csv(okogiefile)
okogie = okogie.dropna()
okogie = okogie.set_index('Shot Type')
okogie = okogie.astype('int')
# Out:
# No Okogie file found

# %%
try:
    newPaulFile = (f'Paul/{newGame}Paul.csv')
    newPaul = pd.read_csv(newPaulFile)
    newPaul = newPaul.dropna()
    newPaul = newPaul.set_index("Shot Type")
    newPaul = newPaul.astype('int')
except(FileNotFoundError):
    print('No Paul file found')

paulfile = ('!Data/Paul.csv')
paul = pd.read_csv(paulfile)
paul = paul.dropna()
paul = paul.set_index('Shot Type')
paul = paul.astype('int')
# Out:
# No Paul file found

# %%
try:
    newPayneFile = (f'Payne/{newGame}Payne.csv')
    newPayne = pd.read_csv(newPayneFile)
    newPayne = newPayne.dropna()
    newPayne = newPayne.set_index("Shot Type")
    newPayne = newPayne.astype('int')
except(FileNotFoundError):
    print('No Payne file found')

paynefile = ('!Data/Payne.csv')
payne = pd.read_csv(paynefile)
payne = payne.dropna()
payne = payne.set_index('Shot Type')
payne = payne.astype('int')

# %%
try:
    newRossFile = (f'Ross/{newGame}Ross.csv')
    newRoss = pd.read_csv(newRossFile)
    newRoss = newRoss.dropna()
    newRoss = newRoss.set_index("Shot Type")
    newRoss = newRoss.astype('int')
except(FileNotFoundError):
    print('No Ross file found')

rossfile = ('!Data/Ross.csv')
ross = pd.read_csv(rossfile)
ross = ross.dropna()
ross = ross.set_index('Shot Type')
ross = ross.astype('int')

# %%
try:
    newShametFile = (f'Shamet/{newGame}Shamet.csv')
    newShamet = pd.read_csv(newShametFile)
    newShamet = newShamet.dropna()
    newShamet = newShamet.set_index("Shot Type")
    newShamet = newShamet.astype('int')
except(FileNotFoundError):
    print('No Shamet file found')

shametfile = ('!Data/Shamet.csv')
shamet = pd.read_csv(shametfile)
shamet = shamet.dropna()
shamet = shamet.set_index('Shot Type')
shamet = shamet.astype('int')

# %%
try:
    newWarrenFile = (f'Warren/{newGame}Warren.csv')
    newWarren = pd.read_csv(newWarrenFile)
    newWarren = newWarren.dropna()
    newWarren = newWarren.set_index("Shot Type")
    newWarren = newWarren.astype('int')
except(FileNotFoundError):
    print('No Warren file found')

warrenfile = ('!Data/Warren.csv')
warren = pd.read_csv(warrenfile)
warren = warren.dropna()
warren = warren.set_index('Shot Type')
warren = warren.astype('int')

# %%
try:
    newOppFile = (f'Opponent/{newGame}.csv')
    newOpp = pd.read_csv(newOppFile)
    newOpp = newOpp.dropna()
    newOpp = newOpp.set_index("Shot Type")
    newOpp = newOpp.astype('int')
except(FileNotFoundError):
    print('No Opp file found')

oppfile = ('!Data/Opp.csv')
opp = pd.read_csv(oppfile)
opp = opp.dropna()
opp = opp.set_index('Shot Type')
opp = opp.astype('int')

# %% [markdown]
# # Add new game data to overall data

# %%
if ayton.columns.equals(newAyton.columns):
    ayton = ayton.add(newAyton)
    ayton.to_csv('!Data/Ayton.csv')
else:
    print("Columns do not match")

# %%
if biyombo.columns.equals(newBiyombo.columns):
    biyombo = biyombo.add(newBiyombo)
    biyombo.to_csv('!Data/Biyombo.csv')
else:
    print("Columns do not match")

# %%
if booker.columns.equals(newBooker.columns):
    booker = booker.add(newBooker)
    booker.to_csv('!Data/Booker.csv')
else:
    print("Columns do not match")

# %%
if craig.columns.equals(newCraig.columns):
    craig = craig.add(newCraig)
    craig.to_csv('!Data/Craig.csv')
else:
    print("Columns do not match")

# %%
if durant.columns.equals(newDurant.columns):
    durant = durant.add(newDurant)
    durant.to_csv('!Data/Durant.csv')
else:
    print("Columns do not match")

# %%
if landale.columns.equals(newLandale.columns):
    landale = landale.add(newLandale)
    landale.to_csv('!Data/Landale.csv')
else:
    print("Columns do not match")

# %%
if lee.columns.equals(newLee.columns):
    lee = lee.add(newLee)
    lee.to_csv('!Data/Lee.csv')
else:
    print("Columns do not match")

# %%
if okogie.columns.equals(newOkogie.columns):
    okogie = okogie.add(newOkogie)
    okogie.to_csv('!Data/Okogie.csv')
else:
    print("Columns do not match")

# %%
if paul.columns.equals(newPaul.columns):
    paul = paul.add(newPaul)
    paul.to_csv('!Data/Paul.csv')
else:
    print("Columns do not match")

# %%
if payne.columns.equals(newPayne.columns):
    payne = payne.add(newPayne)
    payne.to_csv('!Data/Payne.csv')
else:
    print("Columns do not match")

# %%
if ross.columns.equals(newRoss.columns):
    ross = ross.add(newRoss)
    ross.to_csv('!Data/Ross.csv')
else:
    print("Columns do not match")

# %%
if shamet.columns.equals(newShamet.columns):
    shamet = shamet.add(newShamet)
    shamet.to_csv('!Data/Shamet.csv')
else:
    print("Columns do not match")

# %%
if warren.columns.equals(newWarren.columns):
    warren = warren.add(newWarren)
    warren.to_csv('!Data/Warren.csv')
else:
    print("Columns do not match")

# %%
if opp.columns.equals(newOpp.columns):
    opp = opp.add(newOpp)
    opp.to_csv('!Data/Opp.csv')
else:
    print("Columns do not match")

# %%
#newTeam = newAyton
newTeam = newBiyombo
newTeam = newTeam.add(newBooker)
newTeam = newTeam.add(newCraig)
newTeam = newTeam.add(newDurant)
newTeam = newTeam.add(newLandale)
newTeam = newTeam.add(newLee)
#newTeam = newTeam.add(newOkogie)
#newTeam = newTeam.add(newPaul)
newTeam = newTeam.add(newPayne)
newTeam = newTeam.add(newRoss)
newTeam = newTeam.add(newShamet)
newTeam = newTeam.add(newWarren)
newTeam.to_csv(f'../../Nuggets/Opponent/Game6Suns.csv')
newTeam.to_csv(f'Team/{newGame}Team.csv')
newTeam
# Out:
#            PNR BH  PNR SC  DHO BH  DHO SC  DBL BH  DBL SC  ISO  TRAN  ACO  \
# Shot Type
# shoot2FGA       5       1       0       4       0       0   22     9    4
# shoot2FGM       3       1       0       3       0       0    8     6    3
# shoot2FTA       0       0       0       2       0       0    5     7    0
# shoot2FTM       0       0       0       0       0       0    5     5    0
# shoot2TO        0       0       0       0       0       0    2     0    1
# shoot3FGA       1       0       2       0       0       0    3     4    1
# shoot3FGM       1       0       0       0       0       0    1     2    1
# shoot3FTA       0       0       0       0       0       0    0     0    0
# shoot3FTM       0       0       0       0       0       0    0     0    0
# shoot3TO        0       0       0       0       0       0    0     0    0
# pass2FGA        3       0       4       0       0       0    4     2    0
# ...

# %%
teamfile = ('!Data/Team.csv')
team = pd.read_csv(teamfile)
team = team.dropna()
team = team.set_index('Shot Type')
team = team.astype('int')

# %%
if team.columns.equals(newTeam.columns):
    team = team.add(newTeam)
    team.to_csv('!Data/Team.csv')
else:
    print("Columns do not match")

# %% [markdown]
# # Calculate new PPP Data and save files

# %%
bookerStats = PPP(booker)
bookerStats.to_csv('!PPP Stats/bookerStats.csv')
bookerStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.05       23.2        3      44.9         1.16
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.76        3.3        1      50.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler         1.07        7.4        2      50.0          2.0
# DBL Screener              2.0        0.4        0     100.0          2.0
# ISOLATION                1.22       31.9        7      54.5         1.15
# TRANSITION               1.52       19.4        1      70.0         1.63
# Attacking Closeouts      0.92        9.5        2      45.0         1.13
# Catch & Shoot             1.5        1.7        0      50.0          1.5
# Off Ball Screens         1.67        1.2        0      66.7         1.67
# Cutting                   0.5        1.7        0      25.0         0.67
# ...

# %%
newBookerStats = PPP(newBooker)
newBookerStats.to_csv(f'Booker/PPP Stats/{newGame}.csv')
newBookerStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.33       21.4        0      50.0          1.5
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.41       17.4        1      33.3          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.83       42.9        1      36.4         0.33
# TRANSITION               1.47       17.0        0      66.7         1.47
# Attacking Closeouts       1.5        7.1        0      50.0          0.0
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
durantStats = PPP(durant)
durantStats.to_csv('!PPP Stats/durantStats.csv')
durantStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.22       12.6        6      66.7         1.38
# PNR Screener              2.5        0.8        0     100.0          2.5
# DHO Ball Handler          1.8        2.1        0      80.0          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler         1.33        1.2        0      66.7          N/A
# DBL Screener             1.06        0.8        0       0.0         1.06
# ISOLATION                 0.9       48.3       14      42.9         0.94
# TRANSITION               1.32       15.6        3      63.3         1.33
# Attacking Closeouts      1.05        9.9        3      43.8         1.19
# Catch & Shoot            1.31        5.4        0      46.2         1.17
# Off Ball Screens          0.0        2.1        1       0.0          0.0
# Cutting                   1.0        0.8        0      50.0          1.0
# ...

# %%
newDurantStats = PPP(newDurant)
newDurantStats.to_csv(f'Durant/PPP Stats/{newGame}.csv')
newDurantStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          1.5       11.4        2     100.0          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         1.33        8.6        0      66.7          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.04       57.7        3      53.3         1.17
# TRANSITION               0.82       13.9        0      25.0         1.03
# Attacking Closeouts      2.08        8.2        0     100.0          2.0
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0        2.9        0       0.0          0.0
# ...

# %%
aytonStats = PPP(ayton)
aytonStats.to_csv('!PPP Stats/aytonStats.csv')
aytonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             0.94       27.4        2      53.3         1.07
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              2.0        1.6        0     100.0          2.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener             1.43        7.9        0      75.0         1.43
# ISOLATION                 1.0       21.0        2      54.5          0.8
# TRANSITION                0.4        8.1        3      50.0          1.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0        1.6        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  1.15       18.3        0      60.0         1.26
# ...

# %%
newAytonStats = PPP(newAyton)
newAytonStats.to_csv(f'Ayton/PPP Stats/{newGame}.csv')
newAytonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              2.0        7.7        0     100.0          2.0
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              2.0        7.7        0     100.0          2.0
# ISOLATION                1.33       23.1        0      66.7          2.0
# TRANSITION                0.0        7.7        1       N/A          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0        7.7        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   1.0       46.2        0      50.0          1.2
# ...

# %%
paulStats = PPP(paul)
paulStats.to_csv('!PPP Stats/paulStats.csv')
paulStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.17       39.6        1      57.1         1.25
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        2.6        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler         0.67        7.7        0      33.3          1.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 1.4       16.5        0      66.7          1.0
# TRANSITION                1.4       12.8        0      60.0          2.0
# Attacking Closeouts       1.0       12.8        0      40.0          1.0
# Catch & Shoot             0.0        5.1        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0        2.6        0       0.0          0.0
# ...

# %%
newPaulStats = PPP(newPaul)
newPaulStats.to_csv(f'Paul/PPP Stats/{newGame}.csv')
newPaulStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.38       42.1        0      62.5          1.2
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        5.3        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          0.0       10.5        0       0.0          0.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 2.0        5.3        0     100.0          N/A
# TRANSITION               0.67       15.8        0      33.3          N/A
# Attacking Closeouts       1.0       10.5        0      50.0          2.0
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0        5.3        0       0.0          0.0
# ...

# %%
biyomboStats = PPP(biyombo)
biyomboStats.to_csv('!PPP Stats/biyomboStats.csv')
biyomboStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              0.5       66.7        2      50.0         0.67
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0       14.7        0       N/A          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0       16.7        0       0.0          0.0
# ...

# %%
newBiyomboStats = PPP(newBiyombo)
newBiyomboStats.to_csv(f'Biyombo/PPP Stats/{newGame}.csv')
newBiyomboStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0       88.0        0       N/A          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
craigStats = PPP(craig)
craigStats.to_csv('!PPP Stats/craigStats.csv')
craigStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       10.0        0       0.0          0.0
# TRANSITION                0.0       10.0        0       0.0          0.0
# Attacking Closeouts       2.0       10.0        0     100.0          2.0
# Catch & Shoot             0.5       60.0        0      16.7          0.5
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newCraigStats = PPP(newCraig)
newCraigStats.to_csv(f'Craig/PPP Stats/{newGame}.csv')
newCraigStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       33.3        0       0.0          0.0
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       2.0       33.3        0     100.0          2.0
# Catch & Shoot             0.0       33.3        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
landaleStats = PPP(landale)
landaleStats.to_csv('!PPP Stats/landaleStats.csv')
landaleStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             1.14       25.0        1      66.7          1.6
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             1.25       28.6        0      62.5         1.67
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 1.6        6.7        0     100.0          1.6
# TRANSITION                2.0       14.3        0     100.0          2.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  1.09        9.9        0       0.0         1.09
# ...

# %%
newLandaleStats = PPP(newLandale)
newLandaleStats.to_csv(f'Landale/PPP Stats/{newGame}.csv')
newLandaleStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             0.67       30.0        1      50.0          2.0
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              1.2       50.0        0      60.0          1.5
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                2.0       10.0        0     100.0          2.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   1.7       17.6        0       N/A          1.7
# ...

# %%
leeStats = PPP(lee)
leeStats.to_csv('!PPP Stats/leeStats.csv')
leeStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        9.1        0       0.0          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0        9.1        0       0.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                3.0        9.1        0     100.0          3.0
# Attacking Closeouts       2.0        9.1        0     100.0          2.0
# Catch & Shoot            0.33       54.5        0      16.7          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0        9.1        0       0.0          0.0
# ...

# %%
newLeeStats = PPP(newLee)
newLeeStats.to_csv(f'Lee/PPP Stats/{newGame}.csv')
newLeeStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0       50.0        0       0.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       2.0       50.0        0     100.0          2.0
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
okogieStats = PPP(okogie)
okogieStats.to_csv('!PPP Stats/okogieStats.csv')
okogieStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             0.67       14.3        0      33.3          0.0
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              2.0        4.8        0     100.0          2.0
# ISOLATION                 0.0        4.8        0       0.0          N/A
# TRANSITION               1.43       23.2        0      75.0         1.29
# Attacking Closeouts      0.67       14.3        1      50.0          0.0
# Catch & Shoot             0.0       28.6        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   2.0        4.8        0     100.0          2.0
# ...

# %%
newOkogieStats = PPP(newOkogie)
newOkogieStats.to_csv(f'Okogie/PPP Stats/{newGame}.csv')
newOkogieStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION               0.53       62.7        0       0.0         0.53
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0       66.7        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
payneStats = PPP(payne)
payneStats.to_csv('!PPP Stats/payneStats.csv')
payneStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         0.98       25.2        1      47.4         1.11
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          1.5        2.5        0      50.0          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.4       12.2        1      12.5          0.0
# TRANSITION               1.78       24.9        2      87.5         1.92
# Attacking Closeouts      0.58       14.8        4      37.5         0.88
# Catch & Shoot             1.0       18.5        0      33.3         1.07
# Off Ball Screens          0.0        1.2        1       N/A          N/A
# Cutting                   0.0        1.2        0       0.0          0.0
# ...

# %%
newPayneStats = PPP(newPayne)
newPayneStats.to_csv(f'Payne/PPP Stats/{newGame}.csv')
newPayneStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.14       28.0        1      66.7          1.5
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          0.0        4.0        0       0.0          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.41       19.5        1       0.0          0.0
# TRANSITION               1.64       29.3        1      80.0         2.25
# Attacking Closeouts       1.5        8.0        1     100.0          3.0
# Catch & Shoot             3.0       16.0        0     100.0          3.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
rossStats = PPP(ross)
rossStats.to_csv('!PPP Stats/rossStats.csv')
rossStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          2.0        8.3        0     100.0          2.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              0.0        4.2        0       0.0          0.0
# ISOLATION                 0.0        8.3        0       0.0          0.0
# TRANSITION                2.0        4.2        0     100.0          N/A
# Attacking Closeouts      1.14        3.7        0       N/A          N/A
# Catch & Shoot             1.0       75.0        1      35.3         1.06
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newRossStats = PPP(newRoss)
newRossStats.to_csv(f'Ross/PPP Stats/{newGame}.csv')
newRossStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       20.0        0       0.0          0.0
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0       80.0        1       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
shametStats = PPP(shamet)
shametStats.to_csv('!PPP Stats/shametStats.csv')
shametStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          2.5        5.0        0     100.0          2.5
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        5.0        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 1.0        7.5        1      50.0          1.5
# TRANSITION               1.03       19.4        0      33.3         0.26
# Attacking Closeouts      0.67       22.5        2      42.9         0.67
# Catch & Shoot             1.6       37.5        0      53.3          1.6
# Off Ball Screens          0.0        2.5        0       0.0          0.0
# Cutting                   0.0        2.5        1       N/A          N/A
# ...

# %%
newShametStats = PPP(newShamet)
newShametStats.to_csv(f'Shamet/PPP Stats/{newGame}.csv')
newShametStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        6.2        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 1.5       12.5        0      50.0          1.5
# TRANSITION                1.0       31.2        0      40.0          0.0
# Attacking Closeouts       0.0       12.5        2       N/A          0.0
# Catch & Shoot             1.2       31.2        0      40.0          1.2
# Off Ball Screens          0.0        6.2        0       0.0          0.0
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
warrenStats = PPP(warren)
warrenStats.to_csv('!PPP Stats/warrenStats.csv')
warrenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          2.0        5.0        0     100.0          2.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 1.0       10.0        0      50.0          1.0
# TRANSITION               1.23       24.4        0      50.0         1.55
# Attacking Closeouts      0.51       29.4        0      20.0         0.51
# Catch & Shoot             0.5       30.0        0      16.7          0.5
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   2.0        5.0        0     100.0          N/A
# ...

# %%
newWarrenStats = PPP(newWarren)
newWarrenStats.to_csv(f'Warren/PPP Stats/{newGame}.csv')
newWarrenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                0.0       50.0        0       0.0          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0       50.0        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newTeamStats = PPP(newTeam)
newTeamStats.to_csv(f'Team/PPP Stats/{newGame}.csv')
newTeamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.29       13.0        3      64.3          1.5
# PNR Screener             0.67        2.3        1      50.0          2.0
# DHO Ball Handler         0.68        6.8        1      42.9          0.0
# DHO Screener             0.87        5.3        0      50.0         1.23
# DBL Ball Handler          0.0        0.8        0       0.0          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.88       31.4        5      39.4         0.82
# TRANSITION               1.25       18.3        1      52.6         1.43
# Attacking Closeouts      1.47        8.3        3      85.7          1.5
# Catch & Shoot             1.2       11.5        1      42.9         1.29
# Off Ball Screens          0.0        0.8        0       0.0          0.0
# Cutting                  1.09        2.1        0       0.0         1.09
# ...

# %%
newOppStats = PPP(newOpp)
newOppStats.to_csv(f'Opponent/PPP Stats/{newGame}.csv')
newOppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.08       13.9        0      47.4         1.06
# PNR Screener             1.02        4.5        0      50.0         1.02
# DHO Ball Handler          1.0        4.6        0      42.9          0.8
# DHO Screener              1.0        4.6        0      42.9          1.5
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.35       34.5        6      68.3         1.43
# TRANSITION               1.24       11.6        2      64.3         1.42
# Attacking Closeouts      1.21        7.0        0      55.6         1.16
# Catch & Shoot             1.2        6.5        0      40.0          1.2
# Off Ball Screens         0.67        3.9        0      33.3         0.67
# Cutting                  1.09        6.6        1      50.0         1.36
# ...

# %%
teamStats = PPP(team)
teamStats.to_csv(f'!PPP Stats/TeamRound2.csv')
teamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.13       15.4       11      53.6         1.29
# PNR Screener              1.0        4.0        5      57.1         1.15
# DHO Ball Handler         0.94        1.9        1      50.0          0.0
# DHO Screener              1.1        1.3        0      60.0         1.52
# DBL Ball Handler         1.09        3.1        2      50.0          1.5
# DBL Screener             1.33        1.2        0      62.5         1.33
# ISOLATION                 1.0       28.1       25      46.6         0.95
# TRANSITION               1.44       16.7        9      68.4          1.5
# Attacking Closeouts      0.88       10.1       12      43.1          1.0
# Catch & Shoot            0.96       11.0        1      33.0         0.94
# Off Ball Screens          0.5        1.2        2      25.0         0.62
# Cutting                  0.89        3.3        1      43.5         0.95
# ...

# %%
oppStats = PPP(opp)
oppStats.to_csv('!PPP Stats/oppStats.csv')
oppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.34       15.1        4      60.0         1.25
# PNR Screener              1.2        5.1        4      60.0          1.5
# DHO Ball Handler         0.82        5.1        1      35.0         0.86
# DHO Screener             1.24        4.2        0      50.0         1.02
# DBL Ball Handler         1.04        0.7        0      50.0         1.04
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.21       24.6        8      55.1         1.17
# TRANSITION               1.11       19.4        7      52.2         1.09
# Attacking Closeouts      0.88        4.2        1      28.6         1.17
# Catch & Shoot            0.95        8.9        0      31.6         0.95
# Off Ball Screens         1.24        4.2        4      66.7         1.45
# Cutting                  1.19        4.9        3      60.0         1.22
# ...
