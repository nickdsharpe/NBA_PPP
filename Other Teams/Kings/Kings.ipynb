# %%
import pandas as pd
import time
import json
import numpy as np
np.seterr(invalid='ignore')
import nbimporter
from PPP import PPP

# Set newGame variable
newGame = 'Game2Warriors'
Opp = 'Warriors'

# %% [markdown]
# # Read in new files and load overall files

# %%
# Load new game data if it exists
try:
    newBarnesFile = (f'Barnes/{newGame}Barnes.csv')
    newBarnes = pd.read_csv(newBarnesFile)
    newBarnes = newBarnes.dropna()
    newBarnes = newBarnes.set_index('Shot Type')
    newBarnes = newBarnes.astype('int')
except(FileNotFoundError):
    print('No Barnes File Found.')

# Load overall data
barnesFile = ('!Data/Barnes.csv')
barnes = pd.read_csv(barnesFile)
barnes = barnes.dropna()
barnes = barnes.set_index('Shot Type')
barnes = barnes.astype('int')

# %%
try:
    newFoxFile = (f'Fox/{newGame}Fox.csv')
    newFox = pd.read_csv(newFoxFile)
    newFox = newFox.dropna()
    newFox = newFox.set_index("Shot Type")
    newFox = newFox.astype('int')
except(FileNotFoundError):
    print('No Fox file found')

foxfile = ('!Data/Fox.csv')
fox = pd.read_csv(foxfile)
fox = fox.dropna()
fox = fox.set_index('Shot Type')
fox = fox.astype('int')

# %%
try:
    newHuerterFile = (f'Huerter/{newGame}Huerter.csv')
    newHuerter = pd.read_csv(newHuerterFile)
    newHuerter = newHuerter.dropna()
    newHuerter = newHuerter.set_index("Shot Type")
    newHuerter = newHuerter.astype('int')
except(FileNotFoundError):
    print('No Huerter file found')

huerterfile = ('!Data/Huerter.csv')
huerter = pd.read_csv(huerterfile)
huerter = huerter.dropna()
huerter = huerter.set_index('Shot Type')
huerter = huerter.astype('int')

# %%
try:
    newLenFile = (f'Len/{newGame}Len.csv')
    newLen = pd.read_csv(newLenFile)
    newLen = newLen.dropna()
    newLen = newLen.set_index("Shot Type")
    newLen = newLen.astype('int')
except(FileNotFoundError):
    print('No Len file found')

lenfile = ('!Data/Len.csv')
len = pd.read_csv(lenfile)
len = len.dropna()
len = len.set_index('Shot Type')
len = len.astype('int')

# %%
try:
    newLylesFile = (f'Lyles/{newGame}Lyles.csv')
    newLyles = pd.read_csv(newLylesFile)
    newLyles = newLyles.dropna()
    newLyles = newLyles.set_index("Shot Type")
    newLyles = newLyles.astype('int')
except(FileNotFoundError):
    print('No Lyles file found')

lylesfile = ('!Data/Lyles.csv')
lyles = pd.read_csv(lylesfile)
lyles = lyles.dropna()
lyles = lyles.set_index('Shot Type')
lyles = lyles.astype('int')

# %%
try:
    newMitchellFile = (f'Mitchell/{newGame}Mitchell.csv')
    newMitchell = pd.read_csv(newMitchellFile)
    newMitchell = newMitchell.dropna()
    newMitchell = newMitchell.set_index("Shot Type")
    newMitchell = newMitchell.astype('int')
except(FileNotFoundError):
    print('No Mitchell file found')

mitchellfile = ('!Data/Mitchell.csv')
mitchell = pd.read_csv(mitchellfile)
mitchell = mitchell.dropna()
mitchell = mitchell.set_index('Shot Type')
mitchell = mitchell.astype('int')

# %%
try:
    newMonkFile = (f'Monk/{newGame}Monk.csv')
    newMonk = pd.read_csv(newMonkFile)
    newMonk = newMonk.dropna()
    newMonk = newMonk.set_index("Shot Type")
    newMonk = newMonk.astype('int')
except(FileNotFoundError):
    print('No Monk file found')

monkfile = ('!Data/Monk.csv')
monk = pd.read_csv(monkfile)
monk = monk.dropna()
monk = monk.set_index('Shot Type')
monk = monk.astype('int')

# %%
try:
    newMurrayFile = (f'Murray/{newGame}Murray.csv')
    newMurray = pd.read_csv(newMurrayFile)
    newMurray = newMurray.dropna()
    newMurray = newMurray.set_index("Shot Type")
    newMurray = newMurray.astype('int')
except(FileNotFoundError):
    print('No Murray file found')

murrayfile = ('!Data/Murray.csv')
murray = pd.read_csv(murrayfile)
murray = murray.dropna()
murray = murray.set_index('Shot Type')
murray = murray.astype('int')

# %%
try:
    newSabonisFile = (f'Sabonis/{newGame}Sabonis.csv')
    newSabonis = pd.read_csv(newSabonisFile)
    newSabonis = newSabonis.dropna()
    newSabonis = newSabonis.set_index("Shot Type")
    newSabonis = newSabonis.astype('int')
except(FileNotFoundError):
    print('No Sabonis file found')

sabonisfile = ('!Data/Sabonis.csv')
sabonis = pd.read_csv(sabonisfile)
sabonis = sabonis.dropna()
sabonis = sabonis.set_index('Shot Type')
sabonis = sabonis.astype('int')

# %%
try:
    newOppFile = (f'Opponent/{newGame}.csv')
    newOpp = pd.read_csv(newOppFile)
    newOpp = newOpp.dropna()
    newOpp = newOpp.set_index("Shot Type")
    newOpp = newOpp.astype('int')
except(FileNotFoundError):
    print('No Opp file found')

oppfile = ('!Data/Opp.csv')
opp = pd.read_csv(oppfile)
opp = opp.dropna()
opp = opp.set_index('Shot Type')
opp = opp.astype('int')

# %%
teamfile = ('!Data/TeamRound1.csv')
team = pd.read_csv(teamfile)
team = team.dropna()
team = team.set_index('Shot Type')
team = team.astype('int')

# %% [markdown]
# # Add new game data to overall data

# %%
if barnes.columns.equals(newBarnes.columns):
    barnes = barnes.add(newBarnes)
    barnes.to_csv('!Data/Barnes.csv')
else:
    print("Columns do not match")

# %%
if fox.columns.equals(newFox.columns):
    fox = fox.add(newFox)
    fox.to_csv('!Data/Fox.csv')
else:
    print("Columns do not match")

# %%
if huerter.columns.equals(newHuerter.columns):
    huerter = huerter.add(newHuerter)
    huerter.to_csv('!Data/Huerter.csv')
else:
    print("Columns do not match")

# %%
if len.columns.equals(newLen.columns):
    len = len.add(newLen)
    len.to_csv('!Data/Len.csv')
else:
    print("Columns do not match")

# %%
if lyles.columns.equals(newLyles.columns):
    lyles = lyles.add(newLyles)
    lyles.to_csv('!Data/Lyles.csv')
else:
    print("Columns do not match")

# %%
if mitchell.columns.equals(newMitchell.columns):
    mitchell = mitchell.add(newMitchell)
    mitchell.to_csv('!Data/Mitchell.csv')
else:
    print("Columns do not match")

# %%
if monk.columns.equals(newMonk.columns):
    monk = monk.add(newMonk)
    monk.to_csv('!Data/Monk.csv')
else:
    print("Columns do not match")

# %%
if murray.columns.equals(newMurray.columns):
    murray = murray.add(newMurray)
    murray.to_csv('!Data/Murray.csv')
else:
    print("Columns do not match")

# %%
if sabonis.columns.equals(newSabonis.columns):
    sabonis = sabonis.add(newSabonis)
    sabonis.to_csv('!Data/Sabonis.csv')
else:
    print("Columns do not match")

# %%
if jackson.columns.equals(newJackson.columns):
    jackson = jackson.add(newJackson)
    jackson.to_csv('!Data/Jackson.csv')
else:
    print("Columns do not match")

# %%
if opp.columns.equals(newOpp.columns):
    opp = opp.add(newOpp)
    opp.to_csv('!Data/Opp.csv')
else:
    print("Columns do not match")

# %%
newTeam = newBarnes
newTeam = newTeam.add(newFox)
newTeam = newTeam.add(newHuerter)
newTeam = newTeam.add(newLen)
newTeam = newTeam.add(newLyles)
newTeam = newTeam.add(newMitchell)
newTeam = newTeam.add(newMonk)
newTeam = newTeam.add(newMurray)
newTeam = newTeam.add(newSabonis)
newTeam.to_csv(f'../Warriors/Opponent/Game2Warriors.csv')
newTeam.to_csv(f'Team/{newGame}Team.csv')
newTeam.to_csv(f'!Data/TeamRound1.csv')
newTeam
# Out:
#            PNR BH  PNR SC  DHO BH  DHO SC  DBL BH  DBL SC  ISO  TRAN  ACO  \
# Shot Type
# shoot2FGA      15       2       4       2       0       0   12    11    5
# shoot2FGM       7       1       3       1       0       0    4     8    4
# shoot2FTA       4       0       4       1       0       0    3     0    2
# shoot2FTM       4       0       2       1       0       0    2     0    2
# shoot2TO        0       1       0       0       0       0    3     0    0
# shoot3FGA       4       0       8       0       0       0    2     1    0
# shoot3FGM       3       0       0       0       0       0    0     0    0
# shoot3FTA       0       0       0       0       0       0    0     0    0
# shoot3FTM       0       0       0       0       0       0    0     0    0
# shoot3TO        0       0       0       0       0       0    0     0    0
# pass2FGA        4       1       2       3       0       0    2     4    1
# ...

# %%
if team.columns.equals(newTeam.columns):
    team = team.add(newTeam)
    team.to_csv('!Data/Team.csv')
else:
    print("Columns do not match")

# %% [markdown]
# # Calculate new PPP Data and save files

# %%
foxStats = PPP(fox)
foxStats.to_csv('!PPP Stats/foxStats.csv')
foxStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.17       30.5        0      52.2          1.2
# PNR Screener              0.0        1.1        1       N/A          N/A
# DHO Ball Handler          0.0        3.4        0       0.0          0.0
# DHO Screener              0.0        1.1        0       0.0          N/A
# DBL Ball Handler          0.0        2.3        0       0.0          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.75       27.7        3      33.3         0.68
# TRANSITION               1.52       20.4        1      66.7         1.74
# Attacking Closeouts      0.75        4.6        0      25.0          N/A
# Catch & Shoot            1.29        8.0        0      42.9         1.29
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newFoxStats = PPP(newFox)
newFoxStats.to_csv(f'Fox/PPP Stats/{newGame}.csv')
newFoxStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.31       34.2        0      61.5          1.3
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        7.9        0       0.0          0.0
# DHO Screener              0.0        2.6        0       0.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.61       21.6        2      25.0         0.34
# TRANSITION               1.38       21.1        0      62.5          2.0
# Attacking Closeouts       1.0        7.9        0      33.3          N/A
# Catch & Shoot             1.0        7.9        0      33.3          1.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
sabonisStats = PPP(sabonis)
sabonisStats.to_csv('!PPP Stats/sabonisStats.csv')
sabonisStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        1.6        0       0.0          0.0
# PNR Screener             0.56       14.3        2      33.3          0.0
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             0.66       29.4        0      25.0         1.32
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.75       28.1        2      40.0         0.74
# TRANSITION               0.67        9.7        0      33.3          1.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             1.0        3.2        0      50.0          1.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  1.06        3.0        0       0.0         1.06
# ...

# %%
newSabonisStats = PPP(newSabonis)
newSabonisStats.to_csv(f'Sabonis/PPP Stats/{newGame}.csv')
newSabonisStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        3.2        0       0.0          0.0
# PNR Screener             1.25       12.9        1      66.7          0.0
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             0.65       39.7        0      27.3         1.23
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.93       20.8        0      50.0          1.1
# TRANSITION                1.0        6.5        0      50.0          2.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             2.0        3.2        0     100.0          2.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  1.06        6.1        0       0.0         1.06
# ...

# %%
monkStats = PPP(monk)
monkStats.to_csv('!PPP Stats/monkStats.csv')
monkStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.13       49.8        1      45.5         1.54
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.63       11.5        0      20.0         0.35
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.82        8.9        1      33.3         1.03
# TRANSITION               1.78       12.3        1      75.0         1.26
# Attacking Closeouts      2.08        5.2        0     100.0         2.08
# Catch & Shoot             1.0       10.9        0      33.3          1.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newMonkStats = PPP(newMonk)
newMonkStats.to_csv(f'Monk/PPP Stats/{newGame}.csv')
newMonkStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         0.84       42.4        0      27.3         1.36
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.75       19.0        0      25.0         0.53
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.5       14.3        1      33.3         0.67
# TRANSITION                1.0        7.1        0      50.0          1.0
# Attacking Closeouts       2.0        3.6        0     100.0          2.0
# Catch & Shoot            0.75       14.3        0      25.0         0.75
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
barnesStats = PPP(barnes)
barnesStats.to_csv('!PPP Stats/barnesStats.csv')
barnesStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        3.2        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        6.5        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.83       19.4        0      33.3         0.83
# TRANSITION               1.13       28.6        0      50.0         1.36
# Attacking Closeouts      2.08        9.3        0     100.0         2.08
# Catch & Shoot             0.0       12.9        0       0.0          0.0
# Off Ball Screens         0.76        4.3        0       N/A         0.76
# Cutting                   2.0        6.5        0     100.0          2.0
# ...

# %%
newBarnesStats = PPP(newBarnes)
newBarnesStats.to_csv(f'Barnes/PPP Stats/{newGame}.csv')
newBarnesStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        5.9        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0       11.8        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       17.6        0       0.0          0.0
# TRANSITION                1.5       23.5        0      75.0          2.0
# Attacking Closeouts      2.08       16.9        0     100.0         2.08
# Catch & Shoot             0.0       11.8        0       0.0          0.0
# Off Ball Screens         0.76        7.8        0       N/A         0.76
# Cutting                   2.0        5.9        0     100.0          2.0
# ...

# %%
huerterStats = PPP(huerter)
huerterStats.to_csv('!PPP Stats/huerterStats.csv')
huerterStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        2.9        0       0.0          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.76       33.9        1      40.0         0.79
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0        2.9        0       0.0          0.0
# TRANSITION                0.4       14.3        1      25.0         0.67
# Attacking Closeouts       1.5       11.4        1     100.0          2.0
# Catch & Shoot            0.75       22.9        0      25.0         0.75
# Off Ball Screens         0.67        8.6        0      33.3          0.0
# Cutting                   0.0        2.9        0       0.0          0.0
# ...

# %%
newHuerterStats = PPP(newHuerter)
newHuerterStats.to_csv(f'Huerter/PPP Stats/{newGame}.csv')
newHuerterStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         1.19       36.8        0      60.0         1.19
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                0.0       18.8        1       0.0          0.0
# Attacking Closeouts       1.0       12.5        1     100.0          2.0
# Catch & Shoot             1.2       31.2        0      40.0          1.2
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
lenStats = PPP(len)
lenStats.to_csv('!PPP Stats/lenStats.csv')
lenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              1.0       50.0        1      66.7          2.0
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       12.5        1       N/A          0.0
# TRANSITION                0.0       12.5        0       0.0          0.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   2.0       25.0        0     100.0          2.0
# ...

# %%
newLenStats = PPP(newLen)
newLenStats.to_csv(f'Len/PPP Stats/{newGame}.csv')
newLenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              1.0       50.0        1     100.0          2.0
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                0.0       25.0        0       0.0          0.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   2.0       25.0        0     100.0          2.0
# ...

# %%
lylesStats = PPP(lyles)
lylesStats.to_csv('!PPP Stats/lylesStats.csv')
lylesStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                1.5       16.7        1     100.0          3.0
# Attacking Closeouts      1.06       15.7        1       N/A          N/A
# Catch & Shoot            1.29       58.3        0      42.9         1.29
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newLylesStats = PPP(newLyles)
newLylesStats.to_csv(f'Lyles/PPP Stats/{newGame}.csv')
newLylesStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                0.0       25.0        1       N/A          N/A
# Attacking Closeouts      1.06       47.0        1       N/A          N/A
# Catch & Shoot             0.0       50.0        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
mitchellStats = PPP(mitchell)
mitchellStats.to_csv('!PPP Stats/mitchellStats.csv')
mitchellStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.55       16.2        0      66.7         2.08
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        4.2        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.67       12.5        0      33.3          0.0
# TRANSITION                1.5       25.0        1      80.0         0.67
# Attacking Closeouts      1.43       20.3        1      66.7          N/A
# Catch & Shoot             1.0       25.0        0      33.3          1.0
# Off Ball Screens          3.0        4.2        0     100.0          3.0
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newMitchellStats = PPP(newMitchell)
newMitchellStats.to_csv(f'Mitchell/PPP Stats/{newGame}.csv')
newMitchellStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         2.08       20.6        0     100.0         2.08
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        7.1        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 1.0       14.3        0      50.0          0.0
# TRANSITION                2.0       14.3        0     100.0          2.0
# Attacking Closeouts      1.74       20.6        0      50.0          N/A
# Catch & Shoot             1.2       35.7        0      40.0          1.2
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
murrayStats = PPP(murray)
murrayStats.to_csv('!PPP Stats/murrayStats.csv')
murrayStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         2.27        9.8        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       11.1        0       0.0          N/A
# TRANSITION                0.0       11.1        1       N/A          N/A
# Attacking Closeouts       0.0       11.1        0       0.0          0.0
# Catch & Shoot             0.0       33.3        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   3.0       11.1        0     100.0          N/A
# ...

# %%
newMurrayStats = PPP(newMurray)
newMurrayStats.to_csv(f'Murray/PPP Stats/{newGame}.csv')
newMurrayStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       25.0        0       0.0          N/A
# TRANSITION                0.0       25.0        1       N/A          N/A
# Attacking Closeouts       0.0       25.0        0       0.0          0.0
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   3.0       25.0        0     100.0          N/A
# ...

# %%
oppStats = PPP(opp)
oppStats.to_csv('!PPP Stats/oppStats.csv')
oppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.45       12.7        5      67.7         1.55
# PNR Screener             1.09        3.6        2      55.6         1.23
# DHO Ball Handler         0.25        3.7        1       9.1         0.38
# DHO Screener             0.67        3.7        1      27.3          0.0
# DBL Ball Handler         1.29        1.2        0      33.3         2.27
# DBL Screener              1.5        0.6        0      50.0          1.5
# ISOLATION                0.97       21.8       13      48.1         0.99
# TRANSITION               0.69       13.7        9      38.2         0.67
# Attacking Closeouts      1.37        6.0        0      52.9         1.23
# Catch & Shoot             1.0       12.0        0      33.3         0.95
# Off Ball Screens         1.28        8.2        1      47.8         1.47
# Cutting                  1.54        9.8        3      83.3         1.63
# ...

# %%
newOppStats = PPP(newOpp)
newOppStats.to_csv(f'Opponent/PPP Stats/{newGame}.csv')
newOppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.14       14.5        5      56.2         1.42
# PNR Screener             0.71        4.5        2      40.0          0.0
# DHO Ball Handler          0.0        2.5        1       0.0          N/A
# DHO Screener              1.0        1.3        0      50.0          0.0
# DBL Ball Handler         1.74        1.8        0      50.0         2.27
# DBL Screener              3.0        0.6        0     100.0          3.0
# ISOLATION                0.91       25.3        7      45.2         1.09
# TRANSITION               0.67       13.2        5      35.7         0.72
# Attacking Closeouts      0.74        4.3        0      20.0         0.35
# Catch & Shoot            0.94       10.2        0      31.2         0.94
# Off Ball Screens         0.91        7.0        1      40.0         0.86
# Cutting                  1.36       11.7        2      73.3         1.44
# ...

# %%
newTeamStats = PPP(newTeam)
newTeamStats.to_csv(f'Team/PPP Stats/{newGame}.csv')
newTeamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.11       18.3        0      46.4          1.3
# PNR Screener             1.17        3.7        2      75.0         0.67
# DHO Ball Handler         0.64       10.6        0      26.7         0.58
# DHO Screener              0.6        8.2        0      25.0         1.23
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.61       15.1        3      31.6         0.55
# TRANSITION               1.04       14.7        3      57.1         1.33
# Attacking Closeouts      1.37        9.0        2      60.0          1.7
# Catch & Shoot            0.91       13.5        0      31.8         0.91
# Off Ball Screens         0.76        0.8        0       N/A         0.76
# Cutting                  1.84        3.0        0      75.0         1.55
# ...

# %%
teamStats = PPP(team)
teamStats.to_csv(f'Team/PPP Stats/{newGame}.csv')
teamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.12       18.4        1      47.1         1.34
# PNR Screener             0.65        4.2        4      44.4         0.51
# DHO Ball Handler          0.6        7.6        1      23.8         0.45
# DHO Screener             0.62        5.8        0      23.5         1.32
# DBL Ball Handler          0.0        0.6        0       0.0          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.72       17.7        7      34.0          0.7
# TRANSITION               1.23       16.5        6      56.8         1.25
# Attacking Closeouts      1.39        6.5        3      66.7         1.84
# Catch & Shoot            0.88       13.0        0      30.2         0.88
# Off Ball Screens         1.13        1.6        0      50.0         0.93
# Cutting                  1.65        2.4        0      71.4         1.45
# ...
