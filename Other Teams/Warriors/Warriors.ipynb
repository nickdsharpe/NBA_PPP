# %%
import pandas as pd
import time
import json
import numpy as np
np.seterr(invalid='ignore')
import nbimporter
from PPP import PPP

# %%
# Set newGame variable
newGame = 'Game3Kings'
Opp = 'Kings'

# %% [markdown]
# # Read in new files and load overall files

# %%
# Load new game data if it exists
try:
    newCurryFile = (f'Curry/{newGame}Curry.csv')
    newCurry = pd.read_csv(newCurryFile)
    newCurry = newCurry.dropna()
    newCurry = newCurry.set_index('Shot Type')
    newCurry = newCurry.astype('int')
except(FileNotFoundError):
    print('No Curry File Found.')

# Load overall data
curryFile = ('!Data/Round_1/Curry.csv')
curry = pd.read_csv(curryFile)
curry = curry.dropna()
curry = curry.set_index('Shot Type')
curry = curry.astype('int')

# %%
try:
    newDivincenzoFile = (f'Divincenzo/{newGame}Divincenzo.csv')
    newDivincenzo = pd.read_csv(newDivincenzoFile)
    newDivincenzo = newDivincenzo.dropna()
    newDivincenzo = newDivincenzo.set_index("Shot Type")
    newDivincenzo = newDivincenzo.astype('int')
except(FileNotFoundError):
    print('No Divincenzo file found')

divincenzofile = ('!Data/Round_1/Divincenzo.csv')
divincenzo = pd.read_csv(divincenzofile)
divincenzo = divincenzo.dropna()
divincenzo = divincenzo.set_index('Shot Type')
divincenzo = divincenzo.astype('int')

# %%
try:
    newGreenFile = (f'Green/{newGame}Green.csv')
    newGreen = pd.read_csv(newGreenFile)
    newGreen = newGreen.dropna()
    newGreen = newGreen.set_index("Shot Type")
    newGreen = newGreen.astype('int')
except(FileNotFoundError):
    print('No Green file found')

greenfile = ('!Data/Round_1/Green.csv')
green = pd.read_csv(greenfile)
green = green.dropna()
green = green.set_index('Shot Type')
green = green.astype('int')
# Out:
# No Green file found

# %%
try:
    newJamychalFile = (f'Jamychal/{newGame}Jamychal.csv')
    newJamychal = pd.read_csv(newJamychalFile)
    newJamychal = newJamychal.dropna()
    newJamychal = newJamychal.set_index("Shot Type")
    newJamychal = newJamychal.astype('int')
except(FileNotFoundError):
    print('No Jamychal file found')

jamychalfile = ('!Data/Round_1/Jamychal.csv')
jamychal = pd.read_csv(jamychalfile)
jamychal = jamychal.dropna()
jamychal = jamychal.set_index('Shot Type')
jamychal = jamychal.astype('int')

# %%
try:
    newKumingaFile = (f'Kuminga/{newGame}Kuminga.csv')
    newKuminga = pd.read_csv(newKumingaFile)
    newKuminga = newKuminga.dropna()
    newKuminga = newKuminga.set_index("Shot Type")
    newKuminga = newKuminga.astype('int')
except(FileNotFoundError):
    print('No Kuminga file found')

kumingafile = ('!Data/Round_1/Kuminga.csv')
kuminga = pd.read_csv(kumingafile)
kuminga = kuminga.dropna()
kuminga = kuminga.set_index('Shot Type')
kuminga = kuminga.astype('int')

# %%
try:
    newLooneyFile = (f'Looney/{newGame}Looney.csv')
    newLooney = pd.read_csv(newLooneyFile)
    newLooney = newLooney.dropna()
    newLooney = newLooney.set_index("Shot Type")
    newLooney = newLooney.astype('int')
except(FileNotFoundError):
    print('No Looney file found')

looneyfile = ('!Data/Round_1/Looney.csv')
looney = pd.read_csv(looneyfile)
looney = looney.dropna()
looney = looney.set_index('Shot Type')
looney = looney.astype('int')

# %%
try:
    newMoodyFile = (f'Moody/{newGame}Moody.csv')
    newMoody = pd.read_csv(newMoodyFile)
    newMoody = newMoody.dropna()
    newMoody = newMoody.set_index("Shot Type")
    newMoody = newMoody.astype('int')
except(FileNotFoundError):
    print('No Moody file found')

moodyfile = ('!Data/Round_1/Moody.csv')
moody = pd.read_csv(moodyfile)
moody = moody.dropna()
moody = moody.set_index('Shot Type')
moody = moody.astype('int')

# %%
try:
    newPaytonFile = (f'Payton/{newGame}Payton.csv')
    newPayton = pd.read_csv(newPaytonFile)
    newPayton = newPayton.dropna()
    newPayton = newPayton.set_index("Shot Type")
    newPayton = newPayton.astype('int')
except(FileNotFoundError):
    print('No Payton file found')

paytonfile = ('!Data/Round_1/Payton.csv')
payton = pd.read_csv(paytonfile)
payton = payton.dropna()
payton = payton.set_index('Shot Type')
payton = payton.astype('int')
# Out:
# No Payton file found

# %%
try:
    newPooleFile = (f'Poole/{newGame}Poole.csv')
    newPoole = pd.read_csv(newPooleFile)
    newPoole = newPoole.dropna()
    newPoole = newPoole.set_index("Shot Type")
    newPoole = newPoole.astype('int')
except(FileNotFoundError):
    print('No Poole file found')

poolefile = ('!Data/Round_1/Poole.csv')
poole = pd.read_csv(poolefile)
poole = poole.dropna()
poole = poole.set_index('Shot Type')
poole = poole.astype('int')

# %%
try:
    newThompsonFile = (f'Thompson/{newGame}Thompson.csv')
    newThompson = pd.read_csv(newThompsonFile)
    newThompson = newThompson.dropna()
    newThompson = newThompson.set_index("Shot Type")
    newThompson = newThompson.astype('int')
except(FileNotFoundError):
    print('No Thompson file found')

thompsonfile = ('!Data/Round_1/Thompson.csv')
thompson = pd.read_csv(thompsonfile)
thompson = thompson.dropna()
thompson = thompson.set_index('Shot Type')
thompson = thompson.astype('int')

# %%
try:
    newWigginsFile = (f'Wiggins/{newGame}Wiggins.csv')
    newWiggins = pd.read_csv(newWigginsFile)
    newWiggins = newWiggins.dropna()
    newWiggins = newWiggins.set_index("Shot Type")
    newWiggins = newWiggins.astype('int')
except(FileNotFoundError):
    print('No Wiggins file found')

wigginsfile = ('!Data/Round_1/Wiggins.csv')
wiggins = pd.read_csv(wigginsfile)
wiggins = wiggins.dropna()
wiggins = wiggins.set_index('Shot Type')
wiggins = wiggins.astype('int')

# %%
try:
    newOppFile = (f'Opponent/{newGame}.csv')
    newOpp = pd.read_csv(newOppFile)
    newOpp = newOpp.dropna()
    newOpp = newOpp.set_index("Shot Type")
    newOpp = newOpp.astype('int')
except(FileNotFoundError):
    print('No Opp file found')

oppfile = ('!Data/Round_1/Opp.csv')
opp = pd.read_csv(oppfile)
opp = opp.dropna()
opp = opp.set_index('Shot Type')
opp = opp.astype('int')

# %%
teamfile = ('!Data/Round_1/Team.csv')
team = pd.read_csv(teamfile)
team = team.dropna()
team = team.set_index('Shot Type')
team = team.astype('int')

# %% [markdown]
# # Add new game data to overall data

# %%
if curry.columns.equals(newCurry.columns):
    curry = curry.add(newCurry)
    curry.to_csv('!Data/Round_1/Curry.csv')
else:
    print("Columns do not match")

# %%
if divincenzo.columns.equals(newDivincenzo.columns):
    divincenzo = divincenzo.add(newDivincenzo)
    divincenzo.to_csv('!Data/Round_1/Divincenzo.csv')
else:
    print("Columns do not match")

# %%
if green.columns.equals(newGreen.columns):
    green = green.add(newGreen)
    green.to_csv('!Data/Round_1/Green.csv')
else:
    print("Columns do not match")

# %%
if jamychal.columns.equals(newJamychal.columns):
    jamychal = jamychal.add(newJamychal)
    jamychal.to_csv('!Data/Round_1/Jamychal.csv')
else:
    print("Columns do not match")

# %%
if kuminga.columns.equals(newKuminga.columns):
    kuminga = kuminga.add(newKuminga)
    kuminga.to_csv('!Data/Round_1/Kuminga.csv')
else:
    print("Columns do not match")

# %%
if looney.columns.equals(newLooney.columns):
    looney = looney.add(newLooney)
    looney.to_csv('!Data/Round_1/Looney.csv')
else:
    print("Columns do not match")

# %%
if moody.columns.equals(newMoody.columns):
    moody = moody.add(newMoody)
    moody.to_csv('!Data/Round_1/Moody.csv')
else:
    print("Columns do not match")

# %%
if payton.columns.equals(newPayton.columns):
    payton = payton.add(newPayton)
    payton.to_csv('!Data/Round_1/Payton.csv')
else:
    print("Columns do not match")

# %%
if poole.columns.equals(newPoole.columns):
    poole = poole.add(newPoole)
    poole.to_csv('!Data/Round_1/Poole.csv')
else:
    print("Columns do not match")

# %%
if thompson.columns.equals(newThompson.columns):
    thompson = thompson.add(newThompson)
    thompson.to_csv('!Data/Round_1/Thompson.csv')
else:
    print("Columns do not match")

# %%
if wiggins.columns.equals(newWiggins.columns):
    wiggins = wiggins.add(newWiggins)
    wiggins.to_csv('!Data/Round_1/Wiggins.csv')
else:
    print("Columns do not match")

# %%
if opp.columns.equals(newOpp.columns):
    opp = opp.add(newOpp)
    opp.to_csv('!Data/Round_1/Opp.csv')
else:
    print("Columns do not match")

# %%
newTeam = newCurry
newTeam = newTeam.add(newDivincenzo)
#newTeam = newTeam.add(newGreen)
newTeam = newTeam.add(newJamychal)
newTeam = newTeam.add(newKuminga)
newTeam = newTeam.add(newLooney)
newTeam = newTeam.add(newMoody)
#newTeam = newTeam.add(newPayton)
newTeam = newTeam.add(newPoole)
newTeam = newTeam.add(newThompson)
newTeam = newTeam.add(newWiggins)
newTeam.to_csv(f'../{Opp}/Opponent/Game3Warriors.csv')
newTeam.to_csv(f'Team/{newGame}Team.csv')
newTeam.to_csv(f'!Data/Round_1/Team.csv')
newTeam
# Out:
#            PNR BH  PNR SC  DHO BH  DHO SC  DBL BH  DBL SC  ISO  TRAN  ACO  \
# Shot Type
# shoot2FGA       4       0       3       2       0       0   12     4    1
# shoot2FGM       1       0       2       0       0       0    3     3    1
# shoot2FTA       2       0       0       0       0       0    5     2    2
# shoot2FTM       2       0       0       0       0       0    3     1    0
# shoot2TO        0       0       1       0       0       0    1     0    0
# shoot3FGA       4       0       2       1       1       0    9     2    1
# shoot3FGM       2       0       1       0       0       0    1     2    0
# shoot3FTA       0       0       0       0       0       0    0     3    0
# shoot3FTM       0       0       0       0       0       0    0     3    0
# shoot3TO        0       0       0       0       0       0    0     0    0
# pass2FGA        1       1       3       3       0       0    6     3    0
# ...

# %%
if team.columns.equals(newTeam.columns):
    team = team.add(newTeam)
    team.to_csv('!Data/Round_1/Team.csv')
else:
    print("Columns do not match")

# %% [markdown]
# # Calculate new PPP Data and save files

# %%
curryStats = PPP(curry)
curryStats.to_csv('!PPP Stats/curryStats.csv')
curryStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.17       27.2        4      54.2         1.39
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.2        8.6        0      10.0          0.5
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler         1.29        3.3        0      33.3         1.06
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.94       29.5        4      39.3         0.72
# TRANSITION               0.97       10.6        2      44.4         1.09
# Attacking Closeouts       1.0        4.3        0      40.0         1.25
# Catch & Shoot             3.0        4.3        0     100.0          3.0
# Off Ball Screens         1.12        6.9        0      37.5         1.29
# Cutting                  2.04        5.1        0     100.0          2.0
# ...

# %%
newCurryStats = PPP(newCurry)
newCurryStats.to_csv(f'Curry/PPP Stats/{newGame}.csv')
newCurryStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.13       21.1        1      42.9         1.64
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.4       11.9        0      20.0          2.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          0.0        2.4        0       0.0          0.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.76       34.4        0      28.6         0.29
# TRANSITION               2.31       10.3        0     100.0         2.59
# Attacking Closeouts       1.0        4.8        0      50.0          2.0
# Catch & Shoot             3.0        4.8        0     100.0          3.0
# Off Ball Screens          1.5        4.8        0      50.0          1.5
# Cutting                  2.06        9.2        0     100.0          2.0
# ...

# %%
divincenzoStats = PPP(divincenzo)
divincenzoStats.to_csv('!PPP Stats/divincenzoStats.csv')
divincenzoStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              0.0        2.9        1       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0        2.9        0       0.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.67       25.7        2      42.9          1.0
# TRANSITION               1.74       19.7        1      80.0         1.14
# Attacking Closeouts      2.08        8.2        0     100.0          2.0
# Catch & Shoot            1.71       20.0        0      57.1          1.5
# Off Ball Screens         1.25       11.4        0      50.0          1.5
# Cutting                  1.74        8.2        0      50.0         2.27
# ...

# %%
newDivincenzoStats = PPP(newDivincenzo)
newDivincenzoStats.to_csv(f'Divincenzo/PPP Stats/{newGame}.csv')
newDivincenzoStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0        5.6        0       0.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.86       38.9        1      50.0          1.0
# TRANSITION                1.8       21.6        0      66.7         1.14
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             1.0       16.7        0      33.3          1.0
# Off Ball Screens          2.0        5.6        0     100.0          N/A
# Cutting                   3.0        5.6        0     100.0          N/A
# ...

# %%
greenStats = PPP(green)
greenStats.to_csv('!PPP Stats/greenStats.csv')
greenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             1.33        6.2        0      66.7          2.0
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             0.62       16.7        0      25.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              0.0        2.1        0       0.0          0.0
# ISOLATION                1.07       38.8        4      50.0         1.06
# TRANSITION                0.8       10.4        1      50.0          1.0
# Attacking Closeouts       2.0        8.3        0      75.0          N/A
# Catch & Shoot             1.0        6.2        0      33.3          1.0
# Off Ball Screens          0.0        2.1        1       N/A          N/A
# Cutting                  1.81        6.9        0     100.0          1.6
# ...

# %%
newGreenStats = PPP(newGreen)
newGreenStats.to_csv(f'Green/PPP Stats/{newGame}.csv')
newGreenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              1.0       11.1        0      50.0          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              1.0       11.1        0      50.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.29       38.9        3      25.0          N/A
# TRANSITION               1.33       16.7        0      66.7          1.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             1.5       11.1        0      50.0          1.5
# Off Ball Screens          0.0        5.6        1       N/A          N/A
# Cutting                   1.6       10.4        0     100.0          1.6
# ...

# %%
kumingaStats = PPP(kuminga)
kumingaStats.to_csv('!PPP Stats/kumingaStats.csv')
kumingaStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 1.0       11.8        1     100.0          1.0
# TRANSITION                0.0       11.8        1       0.0          0.0
# Attacking Closeouts      0.57       10.4        0       N/A         0.57
# Catch & Shoot             0.0       23.5        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  1.65       32.0        0      80.0         1.65
# ...

# %%
newKumingaStats = PPP(newKuminga)
newKumingaStats.to_csv(f'Kuminga/PPP Stats/{newGame}.csv')
newKumingaStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       0.0       12.6        0       N/A          0.0
# Catch & Shoot             0.0       28.6        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  1.33       42.9        0      66.7         1.33
# ...

# %%
looneyStats = PPP(looney)
looneyStats.to_csv('!PPP Stats/looneyStats.csv')
looneyStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             1.35       26.1        1      57.1         1.03
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              1.3       29.4        0      50.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 3.0        2.9        0     100.0          N/A
# TRANSITION                1.0        5.9        1     100.0          2.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens         2.27        2.6        0       N/A         2.27
# Cutting                  1.16       20.2        0      66.7         1.02
# ...

# %%
newLooneyStats = PPP(newLooney)
newLooneyStats.to_csv(f'Looney/PPP Stats/{newGame}.csv')
newLooneyStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              1.5       11.8        0      50.0          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             1.25       47.1        0      50.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 3.0        5.9        0     100.0          N/A
# TRANSITION                0.0        5.9        1       N/A          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   1.0       11.8        0      50.0          0.0
# ...

# %%
pooleStats = PPP(poole)
pooleStats.to_csv('!PPP Stats/pooleStats.csv')
pooleStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          1.2       22.0        1      50.0         1.24
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.33       11.3        1      20.0          0.5
# DHO Screener              0.0        1.9        1       N/A          N/A
# DBL Ball Handler          0.0        1.9        0       0.0          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.38       14.9        0      14.3          0.2
# TRANSITION               0.92       20.5        0      40.0         0.75
# Attacking Closeouts       0.6        9.4        0      20.0         0.75
# Catch & Shoot            0.83       11.3        0      33.3          0.6
# Off Ball Screens         2.17        5.2        0     100.0         2.27
# Cutting                  2.27        1.7        0       N/A         2.27
# ...

# %%
newPooleStats = PPP(newPoole)
newPooleStats.to_csv(f'Poole/PPP Stats/{newGame}.csv')
newPooleStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        8.7        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          1.0        8.7        0      50.0          2.0
# DHO Screener              0.0        4.3        1       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.77       16.9        0      33.3         0.35
# TRANSITION                1.2       21.7        0      60.0         1.33
# Attacking Closeouts       0.0        8.7        0       0.0          0.0
# Catch & Shoot            0.83       26.1        0      33.3          0.6
# Off Ball Screens         2.27        3.8        0       N/A         2.27
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
thompsonStats = PPP(thompson)
thompsonStats.to_csv('!PPP Stats/thompsonStats.csv')
thompsonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          1.6       13.7        0      60.0         1.57
# PNR Screener              0.0        2.7        0       0.0          N/A
# DHO Ball Handler          0.5        8.2        1      20.0          1.0
# DHO Screener              0.0        1.4        0       0.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              3.0        1.4        0     100.0          3.0
# ISOLATION                0.82       21.8        2      38.5         0.76
# TRANSITION               0.88       11.0        2      50.0         0.83
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot            1.17       16.4        0      41.7         1.17
# Off Ball Screens         1.33       23.7        0      50.0         1.31
# Cutting                   0.0        1.4        0       0.0          0.0
# ...

# %%
newThompsonStats = PPP(newThompson)
newThompsonStats.to_csv(f'Thompson/PPP Stats/{newGame}.csv')
newThompsonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0       11.5        0       0.0          0.0
# PNR Screener              0.0        3.8        0       0.0          N/A
# DHO Ball Handler          0.0       11.5        1       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.25       30.8        1      14.3          0.0
# TRANSITION                3.0        3.8        0     100.0          3.0
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot            1.33       23.1        0      50.0         1.33
# Off Ball Screens         1.35       17.1        0      50.0          1.0
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
wigginsStats = PPP(wiggins)
wigginsStats.to_csv('!PPP Stats/wigginsStats.csv')
wigginsStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.67        4.5        1     100.0          2.5
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        3.0        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.01       32.5        3      52.9         0.95
# TRANSITION               1.65       11.8        0      71.4         1.45
# Attacking Closeouts       1.0        7.5        0      40.0          2.0
# Catch & Shoot            0.67       26.9        0      22.2         0.67
# Off Ball Screens          2.0        4.5        0     100.0          2.0
# Cutting                  1.33        9.0        1      80.0          1.6
# ...

# %%
newWigginsStats = PPP(newWiggins)
newWigginsStats.to_csv(f'Wiggins/PPP Stats/{newGame}.csv')
newWigginsStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          2.0        4.8        0     100.0          2.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        9.5        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.14       37.5        2      60.0         1.02
# TRANSITION                2.5        9.5        0     100.0          2.0
# Attacking Closeouts       0.0        4.8        0       0.0          N/A
# Catch & Shoot             1.2       23.8        0      40.0          1.2
# Off Ball Screens          2.0        9.5        0     100.0          2.0
# Cutting                   2.0        4.8        0     100.0          2.0
# ...

# %%
newTeamStats = PPP(newTeam)
newTeamStats.to_csv(f'Team/PPP Stats/{newGame}.csv')
newTeamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         0.81        8.9        1      30.8         1.13
# PNR Screener              1.0        1.8        0      33.3          N/A
# DHO Ball Handler         0.54        7.7        1      25.0         1.17
# DHO Screener              1.0        6.0        1      44.4          0.0
# DBL Ball Handler          0.0        0.6        0       0.0          0.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.79       25.7        4      35.1          0.5
# TRANSITION                1.8       10.2        1      78.6         1.95
# Attacking Closeouts      0.34        3.5        0      20.0         0.69
# Catch & Shoot            1.11       16.7        0      39.3         1.07
# Off Ball Screens         1.65        6.1        0      66.7         1.52
# Cutting                  1.83        8.5        0      83.3         1.68
# ...

# %%
newOppStats = PPP(newOpp)
newOppStats.to_csv(f'Opponent/PPP Stats/{newGame}.csv')
newOppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         0.95       16.4        1      38.1         0.83
# PNR Screener              1.0        2.7        0      50.0          1.0
# DHO Ball Handler         0.92        8.1        1      36.4          0.8
# DHO Screener             0.89        6.1        0      33.3          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.69       16.6        2      26.3         0.86
# TRANSITION               1.11       24.9        4      59.4         1.38
# Attacking Closeouts       0.0        2.7        0       0.0          0.0
# Catch & Shoot            0.63       12.8        0      21.1         0.63
# Off Ball Screens          0.5        2.7        2      50.0          0.5
# Cutting                  1.33        2.0        1     100.0          2.0
# ...

# %%
teamStats = PPP(team)
teamStats.to_csv('!PPP Stats/teamStats.csv')
teamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.28       11.4        6      56.8         1.45
# PNR Screener             1.08        3.0        2      50.0         1.23
# DHO Ball Handler          0.5        5.3        2      20.8         0.87
# DHO Screener             0.82        4.5        2      35.0          0.0
# DBL Ball Handler         1.02        1.0        0      25.0         1.06
# DBL Screener              1.5        0.4        0      50.0          1.5
# ISOLATION                0.89       22.9       16      41.6         0.78
# TRANSITION               1.03       12.1        9      51.1          1.0
# Attacking Closeouts      1.14        5.0        0      45.5         1.11
# Catch & Shoot            1.06       14.0        0      36.2         1.01
# Off Ball Screens         1.38        7.5        1      53.1         1.48
# Cutting                  1.64        9.5        3      83.3         1.66
# ...

# %%
oppStats = PPP(opp)
oppStats.to_csv('!PPP Stats/oppStats.csv')
oppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.07       17.7        2      44.4         1.22
# PNR Screener             0.73        3.7        4      46.2         0.67
# DHO Ball Handler          0.7        7.7        2      28.1         0.58
# DHO Screener             0.71        5.9        0      26.9         1.32
# DBL Ball Handler          0.0        0.4        0       0.0          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.71       17.3        9      31.8         0.75
# TRANSITION               1.18       19.1       10      57.9          1.3
# Attacking Closeouts      1.18        5.3        3      52.6         1.67
# Catch & Shoot            0.81       12.9        0      27.4         0.81
# Off Ball Screens         0.86        1.9        2      50.0         0.72
# Cutting                  1.56        2.3        1      77.8         1.58
# ...
