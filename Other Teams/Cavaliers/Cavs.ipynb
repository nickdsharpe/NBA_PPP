# %%
import pandas as pd
import time
import json
import numpy as np
import nbimporter
from PPP import PPP
np.seterr(invalid='ignore')
newGame = 'Celtics3.6.23'

# %% [markdown]
# # Read in new game files and load overall files

# %%
try:
    newGarlandFile = (f'Garland/Garland{newGame}.csv')
    newGarland = pd.read_csv(newGarlandFile)
    newGarland = newGarland.dropna()
    newGarland = newGarland.set_index('Shot Type')
    newGarland = newGarland.astype('int')
except(FileNotFoundError):
    print('No Garland File Found.')

garlandFile = ('!Data/Garland.csv')
garland = pd.read_csv(garlandFile)
garland = garland.dropna()
garland = garland.set_index('Shot Type')
garland = garland.astype('int')

# %%
try:
    newLeVertFile = (f'LeVert/LeVert{newGame}.csv')
    newLeVert = pd.read_csv(newLeVertFile)
    newLeVert = newLeVert.dropna()
    newLeVert = newLeVert.set_index('Shot Type')
    newLeVert = newLeVert.astype('int')
except(FileNotFoundError):
    print('No LeVert File Found.')

levertfile = ('!Data/LeVert.csv')
levert = pd.read_csv(levertfile)
levert = levert.dropna()
levert = levert.set_index('Shot Type')
levert = levert.astype('int')

# %%
try:
    newMitchellFile = (f'Mitchell/Mitchell{newGame}.csv')
    newMitchell = pd.read_csv(newMitchellFile)
    newMitchell = newMitchell.dropna()
    newMitchell = newMitchell.set_index('Shot Type')
    newMitchell = newMitchell.astype('int')
except(FileNotFoundError):
    print('No Mitchell File Found.')

mitchellfile = ('!Data/Mitchell.csv')
mitchell = pd.read_csv(mitchellfile)
mitchell = mitchell.dropna()
mitchell = mitchell.set_index('Shot Type')
mitchell = mitchell.astype('int')

# %%
try:
    newMobleyFile = (f'Mobley/Mobley{newGame}.csv')
    newMobley = pd.read_csv(newMobleyFile)
    newMobley = newMobley.dropna()
    newMobley = newMobley.set_index('Shot Type')
    newMobley = newMobley.astype('int')
except(FileNotFoundError):
    print('No Mobley File Found.')

mobleyfile = ('!Data/Mobley.csv')
mobley = pd.read_csv(mobleyfile)
mobley = mobley.dropna()
mobley = mobley.set_index('Shot Type')
mobley = mobley.astype('int')

# %% [markdown]
# # Add new game data to overall files

# %%
if garland.columns.equals(newGarland.columns):
    garland = garland.add(newGarland)
    garland.to_csv('!Data/Garland.csv')
else:
    print("Columns do not match")

# %%
if levert.columns.equals(newLeVert.columns):
    levert = levert.add(newLeVert)
    levert.to_csv('!Data/LeVert.csv')
else:
    print("Columns do not match")

# %%
if mitchell.columns.equals(newMitchell.columns):
    mitchell = mitchell.add(newMitchell)
    mitchell.to_csv('!Data/Mitchell.csv')
else:
    print("Columns do not match")

# %%
if mobley.columns.equals(newMobley.columns):
    mobley = mobley.add(newMobley)
    mobley.to_csv('!Data/Mobley.csv')
else:
    print("Columns do not match")

# %% [markdown]
# # Calculate new PPP Stats and save files

# %%
garlandStats = PPP(garland)
garlandStats.to_csv('!PPP Stats/garlandStats.csv')
garlandStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# ALLEN                    1.12      20.7%     50.6%         1.33
# MOBLEY                   1.03      16.9%     50.8%         0.98
# LEVERT                    2.0       0.2%    100.0%          2.0
# MITCHELL                  1.0       1.2%     40.0%          0.0
# OTHERS                   1.25       8.8%     50.0%         1.32
# ISO                      0.97      23.9%     41.4%         0.73
# Transition               1.21      12.4%     53.3%         1.15
# Attacking Closeouts      1.16       7.1%     52.2%         1.21
# Catch & Shoot             1.9       7.0%     65.5%          1.9
# Off Ball Screens         1.63       1.6%     60.0%         1.56
# Cutting                   2.0       0.5%    100.0%          2.0
# Off. Rebounds             N/A       0.0%       N/A          N/A
# PNR / DHO                1.12      47.7%     50.6%         1.19
# TOTAL                    1.16        426     50.4%         1.16
#
# ...

# %%
newGarlandStats = PPP(newGarland)
newGarlandStats.to_csv(f'Garland/PPP Stats/{newGame}.csv')
newGarlandStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# ALLEN                    1.04       8.2%     50.0%         1.14
# MOBLEY                   1.27      22.5%     57.1%          0.5
# LEVERT                    N/A       0.0%       N/A          N/A
# MITCHELL                  3.0       2.9%    100.0%          N/A
# OTHERS                    0.0       5.7%      0.0%          0.0
# ISO                      1.29      20.0%     66.7%          1.0
# Transition               0.67      25.7%     33.3%         0.67
# Attacking Closeouts       2.0       8.6%    100.0%          1.5
# Catch & Shoot             1.0       8.6%     33.3%          1.0
# Off Ball Screens          0.0       2.9%      0.0%          0.0
# Cutting                   N/A       0.0%       N/A          N/A
# Off. Rebounds             N/A       0.0%       N/A          N/A
# PNR / DHO                1.33      34.3%     54.5%          0.5
# TOTAL                    1.09         35     50.0%         0.72
#
# ...

# %%
levertStats = PPP(levert)
levertStats.to_csv('!PPP Stats/levertStats.csv')
levertStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# ALLEN                    1.19      14.1%     55.6%         1.31
# MOBLEY                   0.77      13.6%     33.3%          0.4
# MITCHELL                  3.0       1.3%    100.0%          N/A
# OSMAN                     N/A       0.0%       N/A          N/A
# OTHERS                   1.67       3.9%     66.7%         1.67
# ISO                      1.51      25.8%     70.6%         1.37
# Transition               1.65      14.1%     80.0%         1.84
# Attacking Closeouts       1.5      10.4%     83.3%         1.75
# Catch & Shoot             0.9      13.0%     30.0%          0.9
# Off Ball Screens          0.0       1.3%      0.0%          0.0
# Cutting                   2.0       1.3%    100.0%          2.0
# Off. Rebounds             1.5       2.6%     50.0%          0.0
# PNR / DHO                1.21      31.2%     50.0%         1.14
# TOTAL                    1.32         77     59.4%         1.22
#
# ...

# %%
newLeVertStats = PPP(newLeVert)
newLeVertStats.to_csv(f'LeVert/PPP Stats/{newGame}.csv')
newLeVertStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# ALLEN                    2.27       6.8%       N/A         2.27
# MOBLEY                   1.23      18.8%     50.0%          0.0
# MITCHELL                  3.0       7.7%    100.0%          N/A
# OSMAN                     N/A       0.0%       N/A          N/A
# OTHERS                    N/A       0.0%       N/A          N/A
# ISO                      0.75      30.8%     33.3%          0.0
# Transition                N/A       0.0%       N/A          N/A
# Attacking Closeouts       3.0       7.7%    100.0%          N/A
# Catch & Shoot             1.0      23.1%     33.3%          1.0
# Off Ball Screens          N/A       0.0%       N/A          N/A
# Cutting                   2.0       7.7%    100.0%          2.0
# Off. Rebounds             0.0       7.7%      0.0%          0.0
# PNR / DHO                2.67      23.1%     66.7%          2.0
# TOTAL                    1.33         13     50.0%         0.79
#
# ...

# %%
mitchellStats = PPP(mitchell)
mitchellStats.to_csv('!PPP Stats/MitchellStats.csv')
mitchellStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# ALLEN                    1.07      16.8%     44.8%         1.17
# MOBLEY                   0.77      10.9%     35.1%         0.84
# LEVERT                    2.5       0.5%    100.0%          2.5
# GARLAND                   1.5       0.5%     50.0%          3.0
# OTHERS                    1.4       3.9%     61.5%         1.23
# ISO                      1.33      30.8%     54.3%         1.31
# Transition               1.11      14.1%     56.1%         1.19
# Attacking Closeouts      1.42       7.7%     66.7%         1.44
# Catch & Shoot            0.95       9.9%     31.6%         0.95
# Off Ball Screens         0.77       3.4%     30.8%         0.77
# Cutting                   0.0       0.3%       N/A          N/A
# Off. Rebounds            1.29       1.4%     60.0%         1.29
# PNR / DHO                1.05      32.4%     44.6%         1.14
# TOTAL                    1.15        383     48.6%         1.19
#
# ...

# %%
newMitchellStats = PPP(newMitchell)
newMitchellStats.to_csv(f'Mitchell/PPP Stats/{newGame}.csv')
newMitchellStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# ALLEN                     0.4      10.0%     25.0%         0.67
# MOBLEY                   0.61       9.8%     25.0%         0.75
# LEVERT                    2.5       4.0%    100.0%          2.5
# GARLAND                   3.0       2.0%    100.0%          3.0
# OTHERS                   0.33      12.0%     20.0%          0.0
# ISO                       0.9      26.6%     36.4%         1.29
# Transition               1.06      24.6%     50.0%         0.95
# Attacking Closeouts      1.06       3.8%      0.0%         2.27
# Catch & Shoot             0.0       2.0%      0.0%          0.0
# Off Ball Screens          0.0       4.0%      0.0%          0.0
# Cutting                   N/A       0.0%       N/A          N/A
# Off. Rebounds            2.08       2.9%    100.0%         2.08
# PNR / DHO                0.83      36.0%     37.5%         0.87
# TOTAL                    0.89         50     38.1%          1.0
#
# ...

# %%
mobleyStats = PPP(mobley)
mobleyStats.to_csv('!PPP Stats/mobleyStats.csv')
mobleyStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# MITCHELL                 0.29       7.9%     20.0%         0.34
# GARLAND                  1.68       5.5%     66.7%         1.33
# LEVERT                   1.51       3.8%    100.0%         1.51
# OSMAN                     N/A       0.0%       N/A          N/A
# OTHERS                    2.0       1.1%    100.0%          2.0
# ISO                       0.9      30.8%     47.6%         0.87
# Transition               1.92       7.8%     80.0%         2.25
# Attacking Closeouts      0.85       6.8%     33.3%         1.74
# Catch & Shoot            0.43      16.1%     14.3%         0.43
# Off Ball Screens          N/A       0.0%       N/A          N/A
# Cutting                  1.87      17.2%     86.7%         1.87
# Off. Rebounds             2.0       4.6%    100.0%          2.0
# PNR / DHO                1.13      17.2%     54.5%         1.08
# TOTAL                    1.14         87     54.8%         1.18
#
# ...

# %%
newMobleyStats = PPP(newMobley)
newMobleyStats.to_csv(f'Mobley/PPP Stats/{newGame}.csv')
newMobleyStats
# Out:
#                     Total PPP % of Poss. Total FG% Shooting PPP  \
# MITCHELL                  0.0       8.2%       N/A          0.0
# GARLAND                   1.6       8.2%    100.0%          1.6
# LEVERT                   2.08       6.3%    100.0%         2.08
# OSMAN                     N/A       0.0%       N/A          N/A
# OTHERS                    2.0       4.3%    100.0%          2.0
# ISO                      0.67      26.1%     40.0%          1.0
# Transition                N/A       0.0%       N/A          N/A
# Attacking Closeouts      0.69      12.5%      0.0%         1.06
# Catch & Shoot            0.75      17.4%     25.0%         0.75
# Off Ball Screens          N/A       0.0%       N/A          N/A
# Cutting                   2.0      13.0%    100.0%          2.0
# Off. Rebounds             2.0       4.3%    100.0%          2.0
# PNR / DHO                1.33      26.1%    100.0%          1.6
# TOTAL                    1.08         23     58.8%         1.31
#
# ...
