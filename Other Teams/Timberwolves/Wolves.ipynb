# %%
import pandas as pd
import time
import json
import numpy as np
np.seterr(invalid='ignore')
import nbimporter
from PPP import PPP

# Set newGame variable
newGame = 'Game5Nuggets'
Opp = 'Nuggets'

# %% [markdown]
# # Read in new files and load overall files

# %%
# Load new game data if it exists
try:
    newAndersonFile = (f'Anderson/{newGame}Anderson.csv')
    newAnderson = pd.read_csv(newAndersonFile)
    newAnderson = newAnderson.dropna()
    newAnderson = newAnderson.set_index('Shot Type')
    newAnderson = newAnderson.astype('int')
except(FileNotFoundError):
    print('No Anderson File Found.')

# Load overall data
andersonFile = ('!Data/Playoffs/Anderson.csv')
anderson = pd.read_csv(andersonFile)
anderson = anderson.dropna()
anderson = anderson.set_index('Shot Type')
anderson = anderson.astype('int')
# Out:
# No Anderson File Found.

# %%
try:
    newConleyFile = (f'Conley/{newGame}Conley.csv')
    newConley = pd.read_csv(newConleyFile)
    newConley = newConley.dropna()
    newConley = newConley.set_index("Shot Type")
    newConley = newConley.astype('int')
except(FileNotFoundError):
    print('No Conley file found')

conleyfile = ('!Data/Playoffs/Conley.csv')
conley = pd.read_csv(conleyfile)
conley = conley.dropna()
conley = conley.set_index('Shot Type')
conley = conley.astype('int')

# %%
try:
    newEdwardsFile = (f'Edwards/{newGame}Edwards.csv')
    newEdwards = pd.read_csv(newEdwardsFile)
    newEdwards = newEdwards.dropna()
    newEdwards = newEdwards.set_index("Shot Type")
    newEdwards = newEdwards.astype('int')
except(FileNotFoundError):
    print('No Edwards file found')

edwardsfile = ('!Data/Playoffs/Edwards.csv')
edwards = pd.read_csv(edwardsfile)
edwards = edwards.dropna()
edwards = edwards.set_index('Shot Type')
edwards = edwards.astype('int')

# %%
try:
    newGobertFile = (f'Gobert/{newGame}Gobert.csv')
    newGobert = pd.read_csv(newGobertFile)
    newGobert = newGobert.dropna()
    newGobert = newGobert.set_index("Shot Type")
    newGobert = newGobert.astype('int')
except(FileNotFoundError):
    print('No Gobert file found')

gobertfile = ('!Data/Playoffs/Gobert.csv')
gobert = pd.read_csv(gobertfile)
gobert = gobert.dropna()
gobert = gobert.set_index('Shot Type')
gobert = gobert.astype('int')

# %%
try:
    newKATFile = (f'KAT/{newGame}KAT.csv')
    newKAT = pd.read_csv(newKATFile)
    newKAT = newKAT.dropna()
    newKAT = newKAT.set_index("Shot Type")
    newKAT = newKAT.astype('int')
except(FileNotFoundError):
    print('No KAT file found')

KATfile = ('!Data/Playoffs/KAT.csv')
KAT = pd.read_csv(KATfile)
KAT = KAT.dropna()
KAT = KAT.set_index('Shot Type')
KAT = KAT.astype('int')

# %%
try:
    newMcLaughlinFile = (f'McLaughlin/{newGame}McLaughlin.csv')
    newMcLaughlin = pd.read_csv(newMcLaughlinFile)
    newMcLaughlin = newMcLaughlin.dropna()
    newMcLaughlin = newMcLaughlin.set_index("Shot Type")
    newMcLaughlin = newMcLaughlin.astype('int')
except(FileNotFoundError):
    print('No McLaughlin file found')

mclaughlinfile = ('!Data/Playoffs/McLaughlin.csv')
mclaughlin = pd.read_csv(mclaughlinfile)
mclaughlin = mclaughlin.dropna()
mclaughlin = mclaughlin.set_index('Shot Type')
mclaughlin = mclaughlin.astype('int')
# Out:
# No McLaughlin file found

# %%
try:
    newNAWFile = (f'NAW/{newGame}NAW.csv')
    newNAW = pd.read_csv(newNAWFile)
    newNAW = newNAW.dropna()
    newNAW = newNAW.set_index("Shot Type")
    newNAW = newNAW.astype('int')
except(FileNotFoundError):
    print('No NAW file found')

NAWfile = ('!Data/Playoffs/NAW.csv')
NAW = pd.read_csv(NAWfile)
NAW = NAW.dropna()
NAW = NAW.set_index('Shot Type')
NAW = NAW.astype('int')

# %%
try:
    newNowellFile = (f'Nowell/{newGame}Nowell.csv')
    newNowell = pd.read_csv(newNowellFile)
    newNowell = newNowell.dropna()
    newNowell = newNowell.set_index("Shot Type")
    newNowell = newNowell.astype('int')
except(FileNotFoundError):
    print('No Nowell file found')

nowellfile = ('!Data/Playoffs/Nowell.csv')
nowell = pd.read_csv(nowellfile)
nowell = nowell.dropna()
nowell = nowell.set_index('Shot Type')
nowell = nowell.astype('int')

# %%
try:
    newPrinceFile = (f'Prince/{newGame}Prince.csv')
    newPrince = pd.read_csv(newPrinceFile)
    newPrince = newPrince.dropna()
    newPrince = newPrince.set_index("Shot Type")
    newPrince = newPrince.astype('int')
except(FileNotFoundError):
    print('No Prince file found')

princefile = ('!Data/Playoffs/Prince.csv')
prince = pd.read_csv(princefile)
prince = prince.dropna()
prince = prince.set_index('Shot Type')
prince = prince.astype('int')

# %%
try:
    newRiversFile = (f'Rivers/{newGame}Rivers.csv')
    newRivers = pd.read_csv(newRiversFile)
    newRivers = newRivers.dropna()
    newRivers = newRivers.set_index("Shot Type")
    newRivers = newRivers.astype('int')
except(FileNotFoundError):
    print('No Rivers file found')

riversfile = ('!Data/Playoffs/Rivers.csv')
rivers = pd.read_csv(riversfile)
rivers = rivers.dropna()
rivers = rivers.set_index('Shot Type')
rivers = rivers.astype('int')

# %%
try:
    newOppFile = (f'Opponent/{newGame}.csv')
    newOpp = pd.read_csv(newOppFile)
    newOpp = newOpp.dropna()
    newOpp = newOpp.set_index("Shot Type")
    newOpp = newOpp.astype('int')
except(FileNotFoundError):
    print('No Opp file found')

oppfile = (f'!Data/Playoffs/Opp.csv')
opp = pd.read_csv(oppfile)
opp = opp.dropna()
opp = opp.set_index('Shot Type')
opp = opp.astype('int')

# %% [markdown]
# # Add new game data to overall data

# %%
if anderson.columns.equals(newAnderson.columns):
    anderson = anderson.add(newAnderson)
    anderson.to_csv('!Data/Playoffs/Anderson.csv')
else:
    print("Columns do not match")

# %%
if conley.columns.equals(newConley.columns):
    conley = conley.add(newConley)
    conley.to_csv('!Data/Playoffs/Conley.csv')
else:
    print("Columns do not match")

# %%
if edwards.columns.equals(newEdwards.columns):
    edwards = edwards.add(newEdwards)
    edwards.to_csv('!Data/Playoffs/Edwards.csv')
else:
    print("Columns do not match")

# %%
if gobert.columns.equals(newGobert.columns):
    gobert = gobert.add(newGobert)
    gobert.to_csv('!Data/Playoffs/Gobert.csv')
else:
    print("Columns do not match")

# %%
if KAT.columns.equals(newKAT.columns):
    KAT = KAT.add(newKAT)
    KAT.to_csv('!Data/Playoffs/KAT.csv')
else:
    print("Columns do not match")

# %%
if mclaughlin.columns.equals(newMcLaughlin.columns):
    mclaughlin = mclaughlin.add(newMcLaughlin)
    mclaughlin.to_csv('!Data/Playoffs/McLaughlin.csv')
else:
    print("Columns do not match")

# %%
if NAW.columns.equals(newNAW.columns):
    NAW = NAW.add(newNAW)
    NAW.to_csv('!Data/Playoffs/NAW.csv')
else:
    print("Columns do not match")

# %%
if nowell.columns.equals(newNowell.columns):
    nowell = nowell.add(newNowell)
    nowell.to_csv('!Data/Playoffs/Nowell.csv')
else:
    print("Columns do not match")

# %%
if prince.columns.equals(newPrince.columns):
    prince = prince.add(newPrince)
    prince.to_csv('!Data/Playoffs/Prince.csv')
else:
    print("Columns do not match")

# %%
if rivers.columns.equals(newRivers.columns):
    rivers = rivers.add(newRivers)
    rivers.to_csv('!Data/Playoffs/Rivers.csv')
else:
    print("Columns do not match")

# %%
if opp.columns.equals(newOpp.columns):
    opp = opp.add(newOpp)
    opp.to_csv('!Data/Playoffs/Opp.csv')
else:
    print("Columns do not match")

# %%
#newTeam = newAnderson
newTeam = newConley
#newTeam = newTeam.add(newConley)
newTeam = newTeam.add(newEdwards)
newTeam = newTeam.add(newGobert)
newTeam = newTeam.add(newKAT)
#newTeam = newTeam.add(newMcLaughlin)
newTeam = newTeam.add(newNAW)
newTeam = newTeam.add(newNowell)
newTeam = newTeam.add(newPrince)
newTeam = newTeam.add(newRivers)
newTeam.to_csv(f'../../Nuggets/Opponent/Game5Wolves.csv')
newTeam.to_csv(f'Team/{newGame}Team.csv')
newTeam
# Out:
#            PNR BH  PNR SC  DHO BH  DHO SC  DBL BH  DBL SC  ISO  TRAN  ACO  \
# Shot Type
# shoot2FGA       8       2       2       0       0       0   16     6    6
# shoot2FGM       5       2       2       0       0       0   10     4    4
# shoot2FTA       1       4       1       2       0       0    5     2    2
# shoot2FTM       1       3       1       1       0       0    5     2    2
# shoot2TO        1       1       0       0       0       0    3     1    0
# shoot3FGA       1       0       2       0       1       0    3     3    1
# shoot3FGM       0       0       0       0       0       0    0     0    1
# shoot3FTA       0       0       0       0       0       0    0     0    0
# shoot3FTM       0       0       0       0       0       0    0     0    0
# shoot3TO        0       0       0       0       0       0    0     0    0
# pass2FGA        5       0       0       1       0       0    3     0    2
# ...

# %%
teamfile = (f'!Data/Playoffs/TeamRound1.csv')
team = pd.read_csv(teamfile)
team = team.dropna()
team = team.set_index('Shot Type')
team = team.astype('int')

# %%
if team.columns.equals(newTeam.columns):
    team = team.add(newTeam)
    team.to_csv('!Data/Playoffs/TeamRound1.csv')
else:
    print("Columns do not match")

# %% [markdown]
# # Calculate new PPP Data and save files

# %%
edwardsStats = PPP(edwards)
edwardsStats.to_csv('!PPP Stats/edwardsStats.csv')
edwardsStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.36       28.0        2      60.0          1.5
# PNR Screener              2.0        0.6        0     100.0          2.0
# DHO Ball Handler         1.25        4.5        1      57.1         1.17
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          1.0        1.7        0      33.3          0.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.13       26.4        3      47.5         1.05
# TRANSITION               0.93       18.7        1      37.0         0.99
# Attacking Closeouts      1.27        8.0        1      45.5         1.07
# Catch & Shoot            0.82        6.2        0      27.3          0.9
# Off Ball Screens         1.67        3.4        0      66.7          0.0
# Cutting                   1.6        2.1        0     100.0          1.6
# ...

# %%
newEdwardsStats = PPP(newEdwards)
newEdwardsStats.to_csv(f'Edwards/PPP Stats/{newGame}.csv')
newEdwardsStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.65       21.3        0      71.4          1.2
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          2.0        2.7        0     100.0          2.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          0.0        2.7        0       0.0          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.25       43.2        0      56.2         0.92
# TRANSITION               0.67       16.2        0      33.3          0.8
# Attacking Closeouts      0.69        7.8        0       0.0         1.06
# Catch & Shoot             0.0        2.7        0       0.0          0.0
# Off Ball Screens          3.0        2.7        0     100.0          N/A
# Cutting                  1.14        2.4        0       N/A         1.14
# ...

# %%
KATStats = PPP(KAT)
KATStats.to_csv('!PPP Stats/KATStats.csv')
KATStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.08        6.3        1      50.0          0.0
# PNR Screener             0.93        3.6        1      50.0          1.2
# DHO Ball Handler         0.68        3.7        0      25.0         0.68
# DHO Screener              0.0        3.4        1       0.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              3.0        0.8        0     100.0          3.0
# ISOLATION                0.96       41.8       10      51.6         0.99
# TRANSITION                1.8        4.2        0      80.0          1.8
# Attacking Closeouts      0.85       12.9        4      50.0         1.32
# Catch & Shoot            0.84       14.9        0      25.0         0.88
# Off Ball Screens         1.23        2.1        0      50.0         1.23
# Cutting                  1.29        3.3        0      66.7         1.29
# ...

# %%
newKATStats = PPP(newKAT)
newKATStats.to_csv(f'KAT/PPP Stats/{newGame}.csv')
newKATStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         2.08        4.6        0     100.0          N/A
# PNR Screener             1.14        2.8        0       N/A         1.14
# DHO Ball Handler         0.87       11.1        0      33.3         0.87
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.14       48.3        2      55.6         1.41
# TRANSITION                2.0        3.2        0     100.0          2.0
# Attacking Closeouts       0.5       12.9        0      25.0          1.0
# Catch & Shoot            0.75       12.9        0      25.0         0.75
# Off Ball Screens         2.08        4.6        0     100.0         2.08
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
andersonStats = PPP(anderson)
andersonStats.to_csv('!PPP Stats/andersonStats.csv')
andersonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          1.5        9.7        0      66.7          2.0
# PNR Screener              2.0        3.2        0     100.0          2.0
# DHO Ball Handler          2.0        1.6        0     100.0          N/A
# DHO Screener              1.0        3.2        0      50.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.68       23.8        2      27.3         0.29
# TRANSITION               1.17       19.4        0      58.3         1.43
# Attacking Closeouts      1.02        9.5        2      66.7          0.0
# Catch & Shoot            1.12       12.9        1      42.9          1.2
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  0.88       12.9        0      37.5          0.8
# ...

# %%
newAndersonStats = PPP(newAnderson)
newAndersonStats.to_csv(f'Anderson/PPP Stats/{newGame}.csv')
newAndersonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          2.0        5.3        0     100.0          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          2.0        5.3        0     100.0          N/A
# DHO Screener              2.0        5.3        0     100.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       15.8        2       0.0          0.0
# TRANSITION               1.25       42.1        0      62.5          1.6
# Attacking Closeouts      2.13        9.9        0     100.0          N/A
# Catch & Shoot             1.5       10.5        0      50.0          3.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0       10.5        0       0.0          0.0
# ...

# %%
conleyStats = PPP(conley)
conleyStats.to_csv('!PPP Stats/conleyStats.csv')
conleyStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.13       33.8        3      50.0         1.32
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         1.33        8.2        0      55.6          2.0
# DHO Screener              0.0        2.7        0       0.0          N/A
# DBL Ball Handler         0.83        5.5        0      33.3          0.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.04       13.1        2      50.0          1.0
# TRANSITION               1.31       14.6        0      46.2         1.13
# Attacking Closeouts       1.5       15.1        2      66.7         2.05
# Catch & Shoot             0.0        4.5        0       0.0          0.0
# Off Ball Screens          1.8        4.0        1     100.0          3.0
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newConleyStats = PPP(newConley)
newConleyStats.to_csv(f'Conley/PPP Stats/{newGame}.csv')
newConleyStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          1.6       31.3        1      80.0          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0        4.5        0       0.0          N/A
# DBL Ball Handler          1.5        9.1        0      50.0          0.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.87       15.6        0      33.3          0.0
# TRANSITION               0.69       13.1        0       0.0         1.06
# Attacking Closeouts      1.25       18.2        1      66.7          2.5
# Catch & Shoot             0.0        9.1        0       0.0          0.0
# Off Ball Screens          0.0        4.5        1       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
gobertStats = PPP(gobert)
gobertStats.to_csv('!PPP Stats/gobertStats.csv')
gobertStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             1.16       28.7        4      64.3         0.98
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             1.52       15.2        1      70.0         1.43
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              0.0        1.3        0       0.0          0.0
# ISOLATION                0.29        9.0        0      14.3          0.5
# TRANSITION               0.85        7.5        1      50.0         1.29
# Attacking Closeouts       0.0        2.6        0       0.0          0.0
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          0.0        1.3        1       N/A          N/A
# Cutting                  1.66       21.6        0      83.3         1.66
# ...

# %%
newGobertStats = PPP(newGobert)
newGobertStats.to_csv(f'Gobert/PPP Stats/{newGame}.csv')
newGobertStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             1.23       30.5        2     100.0         1.55
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             1.04       18.0        1     100.0         1.14
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0        6.2        0       0.0          N/A
# TRANSITION                0.0        6.2        0       0.0          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  1.39       27.0        0      66.7         1.39
# ...

# %%
mclaughlinStats = PPP(mclaughlin)
mclaughlinStats.to_csv('!PPP Stats/mclaughlinStats.csv')
mclaughlinStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0       25.0        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       1.0       50.0        0      50.0          0.0
# Catch & Shoot             0.0       25.0        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newMcLaughlinStats = PPP(newMcLaughlin)
newMcLaughlinStats.to_csv(f'McLaughlin/PPP Stats/{newGame}.csv')
newMcLaughlinStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       1.0      100.0        0      50.0          0.0
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
NAWStats = PPP(NAW)
NAWStats.to_csv('!PPP Stats/NAWStats.csv')
NAWStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.29       11.6        0      60.0         1.29
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.5        8.5        1      33.3          0.0
# TRANSITION               1.33        6.4        0      66.7          2.0
# Attacking Closeouts       0.6       21.3        1      33.3         0.67
# Catch & Shoot            1.29       44.7        0      42.9          1.2
# Off Ball Screens          1.5        4.3        0      50.0          1.5
# Cutting                   0.0        4.3        1       0.0          0.0
# ...

# %%
newNAWStats = PPP(newNAW)
newNAWStats.to_csv(f'NAW/PPP Stats/{newGame}.csv')
newNAWStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.45       26.5        0      66.7         1.45
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       1.0       15.4        0      50.0          N/A
# Catch & Shoot            1.12       61.5        0      37.5         1.12
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
nowellStats = PPP(nowell)
nowellStats.to_csv('!PPP Stats/nowellStats.csv')
nowellStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0       20.0        1       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.67       10.0        0      33.3          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0        6.7        0       0.0          0.0
# TRANSITION                0.0        6.7        0       0.0          0.0
# Attacking Closeouts      0.71       37.7        0      30.0         0.56
# Catch & Shoot             1.0       10.0        0      33.3          1.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   1.0        6.7        0      50.0          1.0
# ...

# %%
newNowellStats = PPP(newNowell)
newNowellStats.to_csv(f'Nowell/PPP Stats/{newGame}.csv')
newNowellStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0       50.0        1       N/A          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       2.0       50.0        0     100.0          2.0
# Catch & Shoot             N/A        0.0        0       N/A          N/A
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
princeStats = PPP(prince)
princeStats.to_csv('!PPP Stats/princeStats.csv')
princeStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         0.52        7.5        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0        3.8        1       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 1.0       13.5        1      50.0          1.0
# TRANSITION               0.89       13.0        1      25.0         0.82
# Attacking Closeouts      0.79       22.0        2      33.3         0.68
# Catch & Shoot            1.12       30.8        0      37.5         1.12
# Off Ball Screens         2.43        5.5        0     100.0         2.43
# Cutting                  2.08        5.5        0     100.0         2.13
# ...

# %%
newPrinceStats = PPP(newPrince)
newPrinceStats.to_csv(f'Prince/PPP Stats/{newGame}.csv')
newPrinceStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        6.2        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       12.5        1       0.0          0.0
# TRANSITION               0.67       18.8        1      50.0         0.67
# Attacking Closeouts       1.0       18.8        1      50.0          N/A
# Catch & Shoot             1.2       31.2        0      40.0          1.2
# Off Ball Screens          3.0        6.2        0     100.0          3.0
# Cutting                   2.0        6.2        0     100.0          2.0
# ...

# %%
riversStats = PPP(rivers)
riversStats.to_csv('!PPP Stats/riversStats.csv')
riversStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0        8.3        0       0.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 0.0       33.3        2       0.0          0.0
# TRANSITION                2.5       16.7        0     100.0          2.0
# Attacking Closeouts      2.13       15.7        0     100.0          2.0
# Catch & Shoot            2.25       33.3        0      75.0         2.25
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newRiversStats = PPP(newRivers)
newRiversStats.to_csv(f'Rivers/PPP Stats/{newGame}.csv')
newRiversStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0       33.3        0       0.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts      2.13       62.7        0     100.0          2.0
# Catch & Shoot             0.0       33.3        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newTeamStats = PPP(newTeam)
newTeamStats.to_csv(f'Team/PPP Stats/{newGame}.csv')
newTeamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.48       14.8        2      70.6         1.05
# PNR Screener             1.22        3.9        2     100.0         1.47
# DHO Ball Handler         1.13        3.0        0      50.0         1.13
# DHO Screener             0.61        3.3        1      33.3         1.14
# DBL Ball Handler          1.0        2.1        0      33.3          0.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.07       25.6        3      50.0         1.03
# TRANSITION               0.72        9.5        1      33.3         0.92
# Attacking Closeouts      1.07       12.8        2      46.7         1.65
# Catch & Shoot            0.86       14.4        0      28.6         0.86
# Off Ball Screens         2.03        3.0        1     100.0         2.46
# Cutting                  1.45        4.2        0      75.0         1.45
# ...

# %%
newOppStats = PPP(newOpp)
newOppStats.to_csv(f'Opponent/PPP Stats/{newGame}.csv')
newOppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.34        9.7        0      46.2          1.1
# PNR Screener              2.0        2.5        1     100.0          3.0
# DHO Ball Handler         1.67        3.7        1      80.0         2.67
# DHO Screener              2.0        3.1        0      80.0          0.0
# DBL Ball Handler         0.69        1.8        1       0.0          0.0
# DBL Screener             2.27        0.5        0       N/A         2.27
# ISOLATION                0.74       26.5        6      33.3         0.53
# TRANSITION               1.32       16.9        1      44.4         1.59
# Attacking Closeouts      0.59        5.2        0      25.0         0.92
# Catch & Shoot            0.83       11.1        0      27.8         0.83
# Off Ball Screens         0.31        6.0        0       0.0         0.35
# Cutting                  1.41        8.8        0      66.7         1.52
# ...

# %%
teamStats = PPP(team)
teamStats.to_csv(f'!PPP Stats/Team.csv')
teamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.17       16.6        7      51.5         1.26
# PNR Screener             1.21        4.2        5      68.4         1.14
# DHO Ball Handler         1.06        3.9        2      48.0         0.97
# DHO Screener             0.91        3.1        2      42.1         1.19
# DBL Ball Handler         0.89        1.3        0      33.3          0.0
# DBL Screener              1.5        0.3        0      50.0          1.5
# ISOLATION                0.91       21.4       21      43.0          0.9
# TRANSITION                1.1       12.3        3      47.2         1.16
# Attacking Closeouts       1.0       13.0       12      44.9         1.05
# Catch & Shoot            1.05       12.3        1      34.9         1.05
# Off Ball Screens         1.65        2.7        2      73.3         1.55
# Cutting                  1.37        5.6        1      66.7         1.39
# ...

# %%
oppStats = PPP(opp)
oppStats.to_csv('!PPP Stats/oppStats.csv')
oppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.06       14.7        8      46.2         1.15
# PNR Screener             1.26        3.9        4      63.6         1.23
# DHO Ball Handler         1.07        6.7        4      47.6         1.16
# DHO Screener             1.19        5.4        1      50.0          0.4
# DBL Ball Handler         1.32        1.4        2      71.4          0.5
# DBL Screener             1.84        0.7        0      75.0         1.84
# ISOLATION                1.08       23.7       18      49.6         1.07
# TRANSITION               1.34       17.3        6      59.8         1.33
# Attacking Closeouts      0.85        3.9        3      39.1         0.86
# Catch & Shoot            0.92        8.8        0      31.2         0.89
# Off Ball Screens         0.93        4.2        3      33.3         1.03
# Cutting                  1.31        5.8        2      64.9         1.31
# ...
