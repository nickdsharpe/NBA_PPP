# %%
import pandas as pd
import time
import json
import numpy as np
np.seterr(invalid='ignore')
import nbimporter
from PPP import PPP

# Set newGame variable
newGame = 'Game1Lakers'
Opp = 'Lakers'

# %% [markdown]
# # Read in new files and load overall files

# %%
# Load new game data if it exists
try:
    newMurrayFile = (f'Murray/{newGame}Murray.csv')
    newMurray = pd.read_csv(newMurrayFile)
    newMurray = newMurray.dropna()
    newMurray = newMurray.set_index('Shot Type')
    newMurray = newMurray.astype('int')
except(FileNotFoundError):
    print('No Murray File Found.')
    
# Load current round data
currentMurrayFile = ('!Data/Playoffs/WCF/Murray.csv')
currentMurray = pd.read_csv(currentMurrayFile)
currentMurray = currentMurray.dropna()
currentMurray = currentMurray.set_index('Shot Type')
currentMurray = currentMurray.astype('int')

# Load overall data
murrayFile = ('!Data/Playoffs/Murray.csv')
murray = pd.read_csv(murrayFile)
murray = murray.dropna()
murray = murray.set_index('Shot Type')
murray = murray.astype('int')

# %%
try:
    newJokerFile = (f'Jokic/{newGame}Jokic.csv')
    newJoker = pd.read_csv(newJokerFile)
    newJoker = newJoker.dropna()
    newJoker = newJoker.set_index("Shot Type")
    newJoker = newJoker.astype('int')
except(FileNotFoundError):
    print('No Jokic file found')
    
# Load current round data
currentJokicFile = ('!Data/Playoffs/WCF/Jokic.csv')
currentJokic = pd.read_csv(currentJokicFile)
currentJokic = currentJokic.dropna()
currentJokic = currentJokic.set_index('Shot Type')
currentJokic = currentJokic.astype('int')

jokerfile = ('!Data/Playoffs/Jokic.csv')
joker = pd.read_csv(jokerfile)
joker = joker.dropna()
joker = joker.set_index('Shot Type')
joker = joker.astype('int')

# %%
try:
    newBraunFile = (f'Braun/{newGame}Braun.csv')
    newBraun = pd.read_csv(newBraunFile)
    newBraun = newBraun.dropna()
    newBraun = newBraun.set_index("Shot Type")
    newBraun = newBraun.astype('int')
except(FileNotFoundError):
    print('No Braun file found')
    
# Load current round data
currentBraunFile = ('!Data/Playoffs/WCF/Braun.csv')
currentBraun = pd.read_csv(currentBraunFile)
currentBraun = currentBraun.dropna()
currentBraun = currentBraun.set_index('Shot Type')
currentBraun = currentBraun.astype('int')

braunfile = ('!Data/Playoffs/braun.csv')
braun = pd.read_csv(braunfile)
braun = braun.dropna()
braun = braun.set_index('Shot Type')
braun = braun.astype('int')

# %%
try:
    newGordonFile = (f'Gordon/{newGame}Gordon.csv')
    newGordon = pd.read_csv(newGordonFile)
    newGordon = newGordon.dropna()
    newGordon = newGordon.set_index("Shot Type")
    newGordon = newGordon.astype('int')
except(FileNotFoundError):
    print('No Gordon file found')
    
currentGordonFile = ('!Data/Playoffs/WCF/Gordon.csv')
currentGordon = pd.read_csv(currentGordonFile)
currentGordon = currentGordon.dropna()
currentGordon = currentGordon.set_index('Shot Type')
currentGordon = currentGordon.astype('int')

gordonfile = ('!Data/Playoffs/Gordon.csv')
gordon = pd.read_csv(gordonfile)
gordon = gordon.dropna()
gordon = gordon.set_index('Shot Type')
gordon = gordon.astype('int')

# %%
try:
    newGreenFile = (f'Green/{newGame}Green.csv')
    newGreen = pd.read_csv(newGreenFile)
    newGreen = newGreen.dropna()
    newGreen = newGreen.set_index("Shot Type")
    newGreen = newGreen.astype('int')
except(FileNotFoundError):
    print('No Green file found')
    
currentGreenFile = ('!Data/Playoffs/WCF/Green.csv')
currentGreen = pd.read_csv(currentGreenFile)
currentGreen = currentGreen.dropna()
currentGreen = currentGreen.set_index('Shot Type')
currentGreen = currentGreen.astype('int')

greenfile = ('!Data/Playoffs/Green.csv')
green = pd.read_csv(greenfile)
green = green.dropna()
green = green.set_index('Shot Type')
green = green.astype('int')

# %%
try:
    newBruceFile = (f'Bruce/{newGame}Bruce.csv')
    newBruce = pd.read_csv(newBruceFile)
    newBruce = newBruce.dropna()
    newBruce = newBruce.set_index("Shot Type")
    newBruce = newBruce.astype('int')
except(FileNotFoundError):
    print('No Bruce file found')
    
currentBruceFile = ('!Data/Playoffs/WCF/Bruce.csv')
currentBruce = pd.read_csv(currentBruceFile)
currentBruce = currentBruce.dropna()
currentBruce = currentBruce.set_index('Shot Type')
currentBruce = currentBruce.astype('int')

brucefile = ('!Data/Playoffs/Bruce.csv')
bruce = pd.read_csv(brucefile)
bruce = bruce.dropna()
bruce = bruce.set_index('Shot Type')
bruce = bruce.astype('int')

# %%
try:
    newBryantFile = (f'Bryant/{newGame}Bryant.csv')
    newBryant = pd.read_csv(newBryantFile)
    newBryant = newBryant.dropna()
    newBryant = newBryant.set_index("Shot Type")
    newBryant = newBryant.astype('int')
except(FileNotFoundError):
    print('No Bryant file found')
    
currentBryantFile = ('!Data/Playoffs/Round_2/Bryant.csv')
currentBryant = pd.read_csv(currentBryantFile)
currentBryant = currentBryant.dropna()
currentBryant = currentBryant.set_index('Shot Type')
currentBryant = currentBryant.astype('int')

bryantfile = ('!Data/Playoffs/Bryant.csv')
bryant = pd.read_csv(bryantfile)
bryant = bryant.dropna()
bryant = bryant.set_index('Shot Type')
bryant = bryant.astype('int')

# %%
try:
    newKCPFile = (f'KCP/{newGame}KCP.csv')
    newKCP = pd.read_csv(newKCPFile)
    newKCP = newKCP.dropna()
    newKCP = newKCP.set_index("Shot Type")
    newKCP = newKCP.astype('int')
except(FileNotFoundError):
    print('No KCP file found')
    
currentKCPFile = ('!Data/Playoffs/WCF/KCP.csv')
currentKCP = pd.read_csv(currentKCPFile)
currentKCP = currentKCP.dropna()
currentKCP = currentKCP.set_index('Shot Type')
currentKCP = currentKCP.astype('int')

KCPfile = ('!Data/Playoffs/KCP.csv')
KCP = pd.read_csv(KCPfile)
KCP = KCP.dropna()
KCP = KCP.set_index('Shot Type')
KCP = KCP.astype('int')

# %%
try:
    newMPJFile = (f'MPJ/{newGame}MPJ.csv')
    newMPJ = pd.read_csv(newMPJFile)
    newMPJ = newMPJ.dropna()
    newMPJ = newMPJ.set_index("Shot Type")
    newMPJ = newMPJ.astype('int')
except(FileNotFoundError):
    print('No MPJ file found')
    
currentMPJFile = ('!Data/Playoffs/WCF/MPJ.csv')
currentMPJ = pd.read_csv(currentMPJFile)
currentMPJ = currentMPJ.dropna()
currentMPJ = currentMPJ.set_index('Shot Type')
currentMPJ = currentMPJ.astype('int')

MPJfile = ('!Data/Playoffs/MPJ.csv')
MPJ = pd.read_csv(MPJfile)
MPJ = MPJ.dropna()
MPJ = MPJ.set_index('Shot Type')
MPJ = MPJ.astype('int')

# %%
try:
    newJacksonFile = (f'Jackson/{newGame}Jackson.csv')
    newJackson = pd.read_csv(newJacksonFile)
    newJackson = newJackson.dropna()
    newJackson = newJackson.set_index("Shot Type")
    newJackson = newJackson.astype('int')
except(FileNotFoundError):
    print('No Jackson file found')
    
currentJacksonFile = ('!Data/Playoffs/Round_2/Jackson.csv')
currentJackson = pd.read_csv(currentJacksonFile)
currentJackson = currentJackson.dropna()
currentJackson = currentJackson.set_index('Shot Type')
currentJackson = currentJackson.astype('int')

jacksonfile = ('!Data/Playoffs/Jackson.csv')
jackson = pd.read_csv(jacksonfile)
jackson = jackson.dropna()
jackson = jackson.set_index('Shot Type')
jackson = jackson.astype('int')

# %%
try:
    newOppFile = (f'Opponent/{newGame}.csv')
    newOpp = pd.read_csv(newOppFile)
    newOpp = newOpp.dropna()
    newOpp = newOpp.set_index("Shot Type")
    newOpp = newOpp.astype('int')
except(FileNotFoundError):
    print('No Opp file found')
    
currentOppFile = ('!Data/Playoffs/WCF/OppWCF.csv')
currentOpp = pd.read_csv(currentOppFile)
currentOpp = currentOpp.dropna()
currentOpp = currentOpp.set_index('Shot Type')
currentOpp = currentOpp.astype('int')

oppfile = ('!Data/Opp.csv')
opp = pd.read_csv(oppfile)
opp = opp.dropna()
opp = opp.set_index('Shot Type')
opp = opp.astype('int')

# %% [markdown]
# # Add new game data to overall data

# %%
if murray.columns.equals(newMurray.columns):
    murray = murray.add(newMurray)
    murray.to_csv('!Data/Playoffs/Murray.csv')
    #currentMurray = currentMurray.add(newMurray)
    #currentMurray.to_csv('!Data/Playoffs/WCF/Murray.csv')
else:
    print("Columns do not match")

# %%
if joker.columns.equals(newJoker.columns):
    joker = joker.add(newJoker)
    joker.to_csv('!Data/Playoffs/Jokic.csv')
    #currentJokic = currentJokic.add(newJoker)
    #currentJokic.to_csv('!Data/Playoffs/WCF/Jokic.csv')
else:
    print("Columns do not match")

# %%
if braun.columns.equals(newBraun.columns):
    braun = braun.add(newBraun)
    braun.to_csv('!Data/Playoffs/Braun.csv')
    #currentBraun = currentBraun.add(newBraun)
    #currentBraun.to_csv('!Data/Playoffs/WCF/Braun.csv')
else:
    print("Columns do not match")

# %%
if bruce.columns.equals(newBruce.columns):
    bruce = bruce.add(newBruce)
    bruce.to_csv('!Data/Playoffs/Bruce.csv')
    #currentBruce = currentBruce.add(newBruce)
    #currentBruce.to_csv('!Data/Playoffs/WCF/Bruce.csv')
else:
    print("Columns do not match")

# %%
if gordon.columns.equals(newGordon.columns):
    gordon = gordon.add(newGordon)
    gordon.to_csv('!Data/Playoffs/Gordon.csv')
    #currentGordon = currentGordon.add(newGordon)
    #currentGordon.to_csv('!Data/Playoffs/WCF/Gordon.csv')
else:
    print("Columns do not match")

# %%
if green.columns.equals(newGreen.columns):
    green = green.add(newGreen)
    green.to_csv('!Data/Playoffs/Green.csv')
    #currentGreen = currentGreen.add(newGreen)
    #currentGreen.to_csv('!Data/Playoffs/WCF/Green.csv')
else:
    print("Columns do not match")

# %%
if bryant.columns.equals(newBryant.columns):
    bryant = bryant.add(newBryant)
    bryant.to_csv('!Data/Playoffs/Bryant.csv')
    #currentBryant = currentBryant.add(newBryant)
    #currentBryant.to_csv('!Data/Playoffs/Round_2/Bryant.csv')
else:
    print("Columns do not match")

# %%
if KCP.columns.equals(newKCP.columns):
    KCP = KCP.add(newKCP)
    KCP.to_csv('!Data/Playoffs/KCP.csv')
    #currentKCP = currentKCP.add(newKCP)
    #currentKCP.to_csv('!Data/Playoffs/WCF/KCP.csv')
else:
    print("Columns do not match")

# %%
if MPJ.columns.equals(newMPJ.columns):
    MPJ = MPJ.add(newMPJ)
    MPJ.to_csv('!Data/Playoffs/MPJ.csv')
    #currentMPJ = currentMPJ.add(newMPJ)
    #currentMPJ.to_csv('!Data/Playoffs/WCF/MPJ.csv')
else:
    print("Columns do not match")

# %%
if jackson.columns.equals(newJackson.columns):
    jackson = jackson.add(newJackson)
    jackson.to_csv('!Data/Playoffs/Jackson.csv')
    #currentJackson = currentJackson.add(newJackson)
    #currentJackson.to_csv('!Data/Playoffs/Round_2/Jackson.csv')
else:
    print("Columns do not match")

# %%
if opp.columns.equals(newOpp.columns):
    opp = opp.add(newOpp)
    opp.to_csv('!Data/Playoffs/Opp.csv')
    #currentOpp = currentOpp.add(newOpp)
    #currentOpp.to_csv('!Data/Playoffs/WCF/OppWCF.csv')
else:
    print("Columns do not match")

# %%
newTeam = newMurray
newTeam = newTeam.add(newJoker)
newTeam = newTeam.add(newBraun)
newTeam = newTeam.add(newGordon)
newTeam = newTeam.add(newGreen)
newTeam = newTeam.add(newBruce)
newTeam = newTeam.add(newKCP)
newTeam = newTeam.add(newMPJ)
newTeam.to_csv(f'../Other Teams/Lakers/Opponent/Game1Nuggets.csv')
newTeam.to_csv(f'Team/{newGame}Team.csv')
newTeam
# Out:
#            PNR BH  PNR SC  DHO BH  DHO SC  DBL BH  DBL SC  ISO  TRAN  ACO  \
# Shot Type
# shoot2FGA       5       0       5       1       0       0   14    15    7
# shoot2FGM       3       0       2       0       0       0    8    10    2
# shoot2FTA       2       0       0       2       2       0    4     5    0
# shoot2FTM       2       0       0       2       2       0    3     3    0
# shoot2TO        0       0       0       0       0       0    0     0    0
# shoot3FGA       5       0       5       0       0       1    3     1    1
# shoot3FGM       2       0       2       0       0       1    2     1    0
# shoot3FTA       0       0       0       0       0       0    0     0    0
# shoot3FTM       0       0       0       0       0       0    0     0    0
# shoot3TO        0       0       0       0       0       0    0     1    0
# pass2FGA        1       0       1       5       0       0    7     7    0
# ...

# %%
# Load overall playoff team data
teamfile = ('!Data/Playoffs/Team.csv')
team = pd.read_csv(teamfile)
team = team.dropna()
team = team.set_index('Shot Type')
team = team.astype('int')

# Load current round playoff data
currentTeamfile = ('!Data/Playoffs/WCF/TeamWCF.csv')
currentTeam = pd.read_csv(currentTeamfile)
currentTeam = currentTeam.dropna()
currentTeam = currentTeam.set_index('Shot Type')
currentTeam = currentTeam.astype('int')

# %%
if team.columns.equals(newTeam.columns):
    team = team.add(newTeam)
    team.to_csv('!Data/Playoffs/Team.csv')
    currentTeam = currentTeam.add(newTeam)
    currentTeam.to_csv('!Data/Playoffs/WCF/TeamWCF.csv')
else:
    print("Columns do not match")

# %% [markdown]
# # Calculate new PPP Data and save files

# %%
murrayStats = PPP(murray)
murrayStats.to_csv('!PPP Stats/murrayStats.csv')
murrayStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.24       33.7        8      52.0         1.32
# PNR Screener             1.67        0.7        1     100.0          2.0
# DHO Ball Handler          0.9       14.6        6      40.7         1.07
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler         1.21        2.3        0      55.6         1.02
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.19       24.1        7      54.0         0.99
# TRANSITION               1.24       13.9        2      52.8         1.25
# Attacking Closeouts      1.02        1.4        0      40.0         0.82
# Catch & Shoot            0.92        3.0        0      30.8         0.92
# Off Ball Screens         1.32        3.2        3      62.5         1.69
# Cutting                   1.0        2.3        0      50.0         1.11
# ...

# %%
currentMurrayStats = PPP(currentMurray)
currentMurrayStats.to_csv('!PPP Stats/WCF/MurrayStats.csv')
currentMurrayStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.65       36.3        1      66.7         1.74
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          1.7       19.6        0      60.0         2.67
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.45       22.9        0      66.7         1.33
# TRANSITION               1.23       16.3        0      75.0          1.0
# Attacking Closeouts       0.0        3.3        0       0.0          0.0
# Catch & Shoot             0.0        3.3        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0        3.3        0       0.0          N/A
# ...

# %%
newMurrayStats = PPP(newMurray)
newMurrayStats.to_csv(f'Murray/PPP Stats/{newGame}.csv')
newMurrayStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.65       36.3        1      66.7         1.74
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          1.7       19.6        0      60.0         2.67
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.45       22.9        0      66.7         1.33
# TRANSITION               1.23       16.3        0      75.0          1.0
# Attacking Closeouts       0.0        3.3        0       0.0          0.0
# Catch & Shoot             0.0        3.3        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0        3.3        0       0.0          N/A
# ...

# %%
jokerStats = PPP(joker)
jokerStats.to_csv('!PPP Stats/jokerStats.csv')
jokerStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.06        6.0        4      51.6         1.01
# PNR Screener              1.2        9.6        7      57.8         1.27
# DHO Ball Handler          0.0        0.2        1       N/A          0.0
# DHO Screener             1.16       14.0        0      48.1         0.86
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              2.0        0.7        0      75.0          2.0
# ISOLATION                1.13       39.4       18      52.9         1.14
# TRANSITION               1.61       10.6        2      73.1         1.87
# Attacking Closeouts      0.76        4.4        1      30.4         0.86
# Catch & Shoot            1.31        2.7        0      43.8         1.31
# Off Ball Screens         1.33        2.8        3      70.0         1.42
# Cutting                  1.41        4.2        2      72.2         1.51
# ...

# %%
currentJokicStats = PPP(currentJokic)
currentJokicStats.to_csv('!PPP Stats/WCF/JokicStats.csv')
currentJokicStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        4.0        1       0.0          0.0
# PNR Screener              0.0        2.0        0       0.0          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             1.35       17.8        0      50.0         2.27
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              3.0        2.0        0     100.0          3.0
# ISOLATION                1.35       41.5        1      61.1          1.3
# TRANSITION               0.87       13.8        0      33.3          N/A
# Attacking Closeouts       3.0        2.0        0     100.0          N/A
# Catch & Shoot             3.0        2.0        0     100.0          3.0
# Off Ball Screens         1.33        6.0        1     100.0          2.0
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newJokerStats = PPP(newJoker)
newJokerStats.to_csv(f'Jokic/PPP Stats/{newGame}.csv')
newJokerStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        4.0        1       0.0          0.0
# PNR Screener              0.0        2.0        0       0.0          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener             1.35       17.8        0      50.0         2.27
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              3.0        2.0        0     100.0          3.0
# ISOLATION                1.35       41.5        1      61.1          1.3
# TRANSITION               0.87       13.8        0      33.3          N/A
# Attacking Closeouts       3.0        2.0        0     100.0          N/A
# Catch & Shoot             3.0        2.0        0     100.0          3.0
# Off Ball Screens         1.33        6.0        1     100.0          2.0
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
jacksonStats = PPP(jackson)
jacksonStats.to_csv('!PPP Stats/jacksonStats.csv')
jacksonStats

# %%
newJacksonStats = PPP(newJackson)
newJacksonStats.to_csv(f'Jackson/PPP Stats/{newGame}.csv')
newJacksonStats

# %%
BraunStats = PPP(braun)
BraunStats.to_csv('!PPP Stats/BraunStats.csv')
BraunStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         0.35        8.2        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          2.0        2.9        0     100.0          2.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.67        8.6        1      50.0          1.0
# TRANSITION               1.29       33.3        2      71.4         1.27
# Attacking Closeouts       0.0        5.7        2       N/A          0.0
# Catch & Shoot             1.2       14.3        0      40.0          1.2
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                  1.23       27.9        1      57.1         1.16
# ...

# %%
currentBraunStats = PPP(currentBraun)
currentBraunStats.to_csv('!PPP Stats/WCF/BraunStats.csv')
currentBraunStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0       50.0        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0       50.0        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newBraunStats = PPP(newBraun)
newBraunStats.to_csv(f'Braun/PPP Stats/{newGame}.csv')
newBraunStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0       50.0        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0       50.0        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
gordonStats = PPP(gordon)
gordonStats.to_csv('!PPP Stats/gordonStats.csv')
gordonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.2        2.6        0       0.0          0.0
# PNR Screener             1.29        5.8        1      66.7         1.42
# DHO Ball Handler         1.06        1.0        0       0.0         1.06
# DHO Screener             0.61        5.2        1      14.3         1.06
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener             2.27        0.5        0       N/A         2.27
# ISOLATION                1.22       29.0        6      58.1         1.06
# TRANSITION               1.18       24.6        6      60.6         1.33
# Attacking Closeouts      1.53        3.1        0      60.0         1.74
# Catch & Shoot            0.67        9.5        0      22.2         0.67
# Off Ball Screens          1.6        1.0        0     100.0          1.6
# Cutting                  1.23        8.6        1      69.2         1.32
# ...

# %%
currentGordonStats = PPP(currentGordon)
currentGordonStats.to_csv('!PPP Stats/WCF/GordonStats.csv')
currentGordonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0       10.0        0       0.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.33       15.0        0      66.7          0.0
# TRANSITION               1.14       43.8        2      80.0         1.18
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0       10.0        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newGordonStats = PPP(newGordon)
newGordonStats.to_csv(f'Gordon/PPP Stats/{newGame}.csv')
newGordonStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0       10.0        0       0.0          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.33       15.0        0      66.7          0.0
# TRANSITION               1.14       43.8        2      80.0         1.18
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             0.0       10.0        0       0.0          0.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
greenStats = PPP(green)
greenStats.to_csv('!PPP Stats/greenStats.csv')
greenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener             1.27       11.3        1      50.0         1.36
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              1.0        7.1        0      40.0          1.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              1.0        2.9        0      50.0          1.0
# ISOLATION                1.39       17.4        1      66.7         1.32
# TRANSITION               1.35       12.7        2      66.7         0.82
# Attacking Closeouts      0.82        7.0        1      33.3         0.82
# Catch & Shoot            0.56       22.9        0      18.8         0.56
# Off Ball Screens          0.0        2.7        1       N/A          0.0
# Cutting                   1.2       14.3        1      66.7         1.11
# ...

# %%
currentGreenStats = PPP(currentGreen)
currentGreenStats.to_csv('!PPP Stats/WCF/GreenStats.csv')
currentGreenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0       25.0        0       0.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       0.0       25.0        0       0.0          0.0
# Catch & Shoot             3.0       25.0        0     100.0          3.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0       25.0        1       N/A          0.0
# ...

# %%
newGreenStats = PPP(newGreen)
newGreenStats.to_csv(f'Green/PPP Stats/{newGame}.csv')
newGreenStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          N/A        0.0        0       N/A          N/A
# DHO Screener              0.0       25.0        0       0.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                N/A        0.0        0       N/A          N/A
# Attacking Closeouts       0.0       25.0        0       0.0          0.0
# Catch & Shoot             3.0       25.0        0     100.0          3.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   0.0       25.0        1       N/A          0.0
# ...

# %%
BruceStats = PPP(bruce)
BruceStats.to_csv('!PPP Stats/BruceStats.csv')
BruceStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.19       24.9        3      55.3         1.19
# PNR Screener             1.14        0.5        0       N/A         1.14
# DHO Ball Handler         0.25        4.6        0      12.5         0.33
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler         1.89        2.7        1     100.0         1.06
# DBL Screener              0.0        0.6        1       N/A          N/A
# ISOLATION                0.78       12.4        7      38.5         1.13
# TRANSITION               1.45       29.2        2      67.4         1.41
# Attacking Closeouts       1.8        2.5        1     100.0         1.23
# Catch & Shoot            1.05       11.4        0      35.0         1.05
# Off Ball Screens          1.0        2.3        1      66.7          1.0
# Cutting                  1.03        7.2        2      50.0         1.22
# ...

# %%
currentBruceStats = PPP(currentBruce)
currentBruceStats.to_csv('!PPP Stats/WCF/BruceStats.csv')
currentBruceStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        6.7        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0       20.0        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler         2.66       12.5        0     100.0         2.27
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 3.0        6.7        0     100.0          N/A
# TRANSITION               1.48       49.6        0      71.4         1.71
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             3.0        6.7        0     100.0          3.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newBruceStats = PPP(newBruce)
newBruceStats.to_csv(f'Bruce/PPP Stats/{newGame}.csv')
newBruceStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          0.0        6.7        0       0.0          0.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          0.0       20.0        0       0.0          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler         2.66       12.5        0     100.0         2.27
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 3.0        6.7        0     100.0          N/A
# TRANSITION               1.48       49.6        0      71.4         1.71
# Attacking Closeouts       N/A        0.0        0       N/A          N/A
# Catch & Shoot             3.0        6.7        0     100.0          3.0
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
bryantStats = PPP(bryant)
bryantStats.to_csv('!PPP Stats/bryantStats.csv')
bryantStats

# %%
newBryantStats = PPP(newBryant)
newBryantStats.to_csv(f'Bryant/PPP Stats/{newGame}.csv')
newBryantStats

# %%
KCPStats = PPP(KCP)
KCPStats.to_csv('!PPP Stats/KCPStats.csv')
KCPStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          2.2        3.4        0     100.0         2.33
# PNR Screener              0.0        0.7        1       N/A          N/A
# DHO Ball Handler         1.28       12.9        2      66.7         1.28
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          0.0        0.7        1       N/A          0.0
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                0.76       10.9        1      30.8         0.73
# TRANSITION               1.42       25.7        1      58.1         1.31
# Attacking Closeouts      0.73        7.6        1      40.0          0.8
# Catch & Shoot            1.35       25.5        0      45.9         1.31
# Off Ball Screens         0.33        4.1        0      16.7          0.0
# Cutting                  1.14        7.9        1      60.0         1.25
# ...

# %%
currentKCPStats = PPP(currentKCP)
currentKCPStats.to_csv('!PPP Stats/WCF/KCPStats.csv')
currentKCPStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          2.0        5.3        0     100.0          2.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.67       15.8        1      50.0          1.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                1.0       15.8        0      33.3          0.0
# Attacking Closeouts      1.33       15.8        0      66.7         1.33
# Catch & Shoot            1.29       36.8        0      42.9         1.29
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   2.0       10.5        0     100.0          2.0
# ...

# %%
newKCPStats = PPP(newKCP)
newKCPStats.to_csv(f'KCP/PPP Stats/{newGame}.csv')
newKCPStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          2.0        5.3        0     100.0          2.0
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler         0.67       15.8        1      50.0          1.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 N/A        0.0        0       N/A          N/A
# TRANSITION                1.0       15.8        0      33.3          0.0
# Attacking Closeouts      1.33       15.8        0      66.7         1.33
# Catch & Shoot            1.29       36.8        0      42.9         1.29
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   2.0       10.5        0     100.0          2.0
# ...

# %%
MPJStats = PPP(MPJ)
MPJStats.to_csv('!PPP Stats/MPJStats.csv')
MPJStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          1.0        2.4        0      50.0         0.67
# PNR Screener              2.0        0.6        0     100.0          2.0
# DHO Ball Handler         1.05       13.3        0      38.1         1.01
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.76       10.0        0      75.0         1.66
# TRANSITION               1.14       25.0        1      44.7         1.22
# Attacking Closeouts      0.65        8.3        0      25.0         0.77
# Catch & Shoot            1.22       19.4        0      43.8         1.19
# Off Ball Screens         1.11       12.6        1      44.4         1.23
# Cutting                  1.72        6.3        0      80.0         1.59
# ...

# %%
currentMPJStats = PPP(currentMPJ)
currentMPJStats.to_csv('!PPP Stats/WCF/MPJStats.csv')
currentMPJStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          1.0       21.4        0      33.3          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 3.0        7.1        0     100.0          3.0
# TRANSITION               2.33       21.4        0     100.0          2.5
# Attacking Closeouts       0.0       21.4        0       0.0          0.0
# Catch & Shoot            2.33       21.4        0     100.0         2.33
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newMPJStats = PPP(newMPJ)
newMPJStats.to_csv(f'MPJ/PPP Stats/{newGame}.csv')
newMPJStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler          N/A        0.0        0       N/A          N/A
# PNR Screener              N/A        0.0        0       N/A          N/A
# DHO Ball Handler          1.0       21.4        0      33.3          0.0
# DHO Screener              N/A        0.0        0       N/A          N/A
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                 3.0        7.1        0     100.0          3.0
# TRANSITION               2.33       21.4        0     100.0          2.5
# Attacking Closeouts       0.0       21.4        0       0.0          0.0
# Catch & Shoot            2.33       21.4        0     100.0         2.33
# Off Ball Screens          N/A        0.0        0       N/A          N/A
# Cutting                   N/A        0.0        0       N/A          N/A
# ...

# %%
newTeamStats = PPP(newTeam)
newTeamStats.to_csv(f'Team/PPP Stats/{newGame}.csv')
newTeamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.26       10.1        2      53.8         1.29
# PNR Screener              0.0        0.6        0       0.0          N/A
# DHO Ball Handler         1.01        9.5        1      38.5          1.0
# DHO Screener             1.01        7.6        0      36.4         1.06
# DBL Ball Handler         2.66        1.2        0     100.0         2.27
# DBL Screener              3.0        0.6        0     100.0          3.0
# ISOLATION                1.47       20.8        1      65.5         1.33
# TRANSITION               1.27       21.6        2      64.3         1.35
# Attacking Closeouts      0.78        5.7        0      33.3          0.5
# Catch & Shoot            1.47       10.8        0      52.9         1.47
# Off Ball Screens         1.33        1.9        1     100.0          2.0
# Cutting                   1.0        2.5        1      66.7         1.33
# ...

# %%
newOppStats = PPP(newOpp)
newOppStats.to_csv(f'Opponent/PPP Stats/{newGame}.csv')
newOppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.25       17.2        3      60.0         0.92
# PNR Screener             2.03        4.8        0      83.3         2.04
# DHO Ball Handler         0.67        2.1        0      33.3          2.0
# DHO Screener             0.67        2.1        1      50.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.11       28.1        1      47.2         1.02
# TRANSITION                1.6       16.5        2      76.9         1.67
# Attacking Closeouts      0.89        6.2        0      44.4         0.75
# Catch & Shoot            1.35       13.9        0      45.0          1.5
# Off Ball Screens          0.0        0.7        1       N/A          N/A
# Cutting                   1.8        6.9        0      90.0          1.8
# ...

# %%
currentTeamStats = PPP(currentTeam)
currentTeamStats.to_csv('!PPP Stats/WCF/TeamWCF.csv')
currentTeamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.26       10.1        2      53.8         1.29
# PNR Screener              0.0        0.6        0       0.0          N/A
# DHO Ball Handler         1.01        9.5        1      38.5          1.0
# DHO Screener             1.01        7.6        0      36.4         1.06
# DBL Ball Handler         2.66        1.2        0     100.0         2.27
# DBL Screener              3.0        0.6        0     100.0          3.0
# ISOLATION                1.47       20.8        1      65.5         1.33
# TRANSITION               1.27       21.6        2      64.3         1.35
# Attacking Closeouts      0.78        5.7        0      33.3          0.5
# Catch & Shoot            1.47       10.8        0      52.9         1.47
# Off Ball Screens         1.33        1.9        1     100.0          2.0
# Cutting                   1.0        2.5        1      66.7         1.33
# ...

# %%
currentOppStats = PPP(currentOpp)
currentOppStats.to_csv('!PPP Stats/Round_2/OppWCF.csv')
currentOppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.25       17.2        3      60.0         0.92
# PNR Screener             2.03        4.8        0      83.3         2.04
# DHO Ball Handler         0.67        2.1        0      33.3          2.0
# DHO Screener             0.67        2.1        1      50.0          0.0
# DBL Ball Handler          N/A        0.0        0       N/A          N/A
# DBL Screener              N/A        0.0        0       N/A          N/A
# ISOLATION                1.11       28.1        1      47.2         1.02
# TRANSITION                1.6       16.5        2      76.9         1.67
# Attacking Closeouts      0.89        6.2        0      44.4         0.75
# Catch & Shoot            1.35       13.9        0      45.0          1.5
# Off Ball Screens          0.0        0.7        1       N/A          N/A
# Cutting                   1.8        6.9        0      90.0          1.8
# ...

# %%
teamStats = PPP(team)
teamStats.to_csv(f'!PPP Stats/TeamStats.csv')
teamStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         1.19       13.9       13      52.4         1.21
# PNR Screener             1.26        4.7       10      62.1         1.37
# DHO Ball Handler         0.94        6.3        8      42.5         1.04
# DHO Screener             1.12        5.1        1      46.7         0.87
# DBL Ball Handler         1.16        0.9        2      60.0         0.73
# DBL Screener             1.31        0.4        1      60.0         1.53
# ISOLATION                1.13       25.4       39      52.9         1.09
# TRANSITION               1.36       17.4       16      60.0         1.35
# Attacking Closeouts       0.9        3.8        6      39.6         0.93
# Catch & Shoot            1.03        8.6        0      34.8         1.01
# Off Ball Screens         1.09        3.8        8      48.8         1.21
# Cutting                  1.27        6.3        7      64.6         1.32
# ...

# %%
oppStats = PPP(opp)
oppStats.to_csv('!PPP Stats/oppStats.csv')
oppStats
# Out:
#                     Total PPP % of Poss. Total TO Total FG% Shooting PPP  \
# PNR Ball Handler         0.98       11.7       17      47.4         0.93
# PNR Screener             1.21        6.7        4      50.0         1.16
# DHO Ball Handler         0.65        2.5        0      28.6         0.48
# DHO Screener             1.03        1.9        2      57.1         1.33
# DBL Ball Handler         0.58        0.8        0      16.7         0.26
# DBL Screener              1.0        0.4        0      33.3          1.0
# ISOLATION                0.86       21.5       13      39.2         0.79
# TRANSITION               1.31       19.3       19      69.5         1.35
# Attacking Closeouts      1.03        8.3        8      51.7         1.04
# Catch & Shoot             1.0       13.4        0      33.3         1.02
# Off Ball Screens         1.38        2.0        1      46.2         1.47
# Cutting                  1.07        7.5        7      57.7         1.11
# ...
